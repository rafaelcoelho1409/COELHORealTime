# %%
import pandas as pd

# %%
data = pd.read_pickle("../fastapi_app/river_data.pkl")

# %%
data
# Out:
#                             transaction_id  \
# 0     97a6c8b8-9eb8-46f3-aa9c-44b927606b64
# 1     6bac8f52-e97c-4b16-9309-1eb2fb817896
# 2     24fc0f05-5d62-4444-a6ab-3a87819c868a
# 3     82d1df14-929b-4349-acc9-e92e90d5f303
# 4     590a2675-d837-4c52-83ac-322960418015
# ...                                    ...
# 3596  aad1fe18-c5cb-423c-97af-5e1181a5a732
# 3597  f8741965-680e-4c8d-9ed0-0ee70cde8fc0
# 3598  f95ca5e3-1c10-4d26-8079-05f6f1dc3835
# 3599  f6f0c028-bb2e-4b37-8164-6e9905b528fe
# 3600  b20d3452-1a22-4ec0-83ea-615bfbf062d8
#
#                                    user_id                         timestamp  \
# 0     30b51f05-cbc2-4f04-bdd5-fe76e45abeaf  2025-04-17T15:13:41.280961+00:00
# 1     0b627efc-6d6b-4e22-80f5-19ad34e7b446  2025-04-17T15:13:42.088936+00:00
# 2     4455c4dd-c3ef-4eb0-8d3c-a4c96ebc27c1  2025-04-17T15:13:42.303536+00:00
# 3     4eff4235-ac43-4645-ad93-6209524b0136  2025-04-17T15:13:42.646294+00:00
# ...
