# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle("../fastapi_app/river_data.pkl")

# %%
data
# Out:
#                             transaction_id  \
# 0     dd0c3199-ab85-4d6e-b66e-6300f7c099cf
# 1     33805229-2bcb-448a-8da0-ab594e072eab
# 2     f11dc48f-7f5f-4bbf-8052-45c5b179dae0
# 3     b9070f93-ed70-4c04-bddd-dd776065e5c2
# 4     62630dea-122d-4ebb-b5ac-2a1f229440ee
# ...                                    ...
# 6096  07edee53-801a-4f94-bd01-5568f88bf544
# 6097  aadc2ba7-f8c5-4941-96f8-3dda7a4946c1
# 6098  04c4e954-199a-4320-a32d-193a5df31ced
# 6099  bd171a6c-54c3-4e94-85ba-6171af177274
# 6100  294d58e8-922a-43e6-912f-dde9737afb29
#
#                                    user_id                         timestamp  \
# 0     a7860002-2233-435e-bfe3-325ed97cd4cd  2025-04-19T21:31:22.929191+00:00
# 1     3734da2b-c030-4470-8f98-393670d5ecba  2025-04-19T21:31:23.472979+00:00
# 2     46bc663c-f680-4f52-984c-ede708ad6e72  2025-04-19T21:31:23.725947+00:00
# 3     65793b3b-a8df-4683-a55f-1648def5e69b  2025-04-19T21:31:24.209464+00:00
# 4     bc4dc493-3344-418c-9e0d-7a47e3fc82c0  2025-04-19T21:31:24.489778+00:00
# ...                                    ...                               ...
# 6096  234b864c-9396-4003-b06d-31bca942eda7  2025-04-19T21:59:28.769888+00:00
# 6097  db319b31-4ecb-4f2e-b092-edda8ccf696e  2025-04-19T21:59:28.851751+00:00
# 6098  a58e9d88-56b7-42ab-8f1c-ab104b29efe2  2025-04-19T21:59:28.977000+00:00
# 6099  0ef915f3-fba7-4321-818a-406b78387c47  2025-04-19T21:59:29.460941+00:00
# 6100  607f56a1-6143-4953-b261-f1c9c5713ac4  2025-04-19T21:59:29.699987+00:00
#
#       amount currency   merchant_id product_category transaction_type  \
# 0     435.36      BRL  merchant_188           travel         transfer
# 1     473.96      BRL   merchant_61         gambling         transfer
# 2     468.48      CAD  merchant_110            other         purchase
# 3      29.03      BRL  merchant_159           travel         purchase
# 4     217.83      GBP   merchant_50      electronics          payment
# ...      ...      ...           ...              ...              ...
# 6096   68.70      USD  merchant_143     luxury_items          payment
# 6097  338.58      EUR   merchant_86         gambling       withdrawal
# 6098  403.55      GBP  merchant_171         services         transfer
# 6099  249.81      GBP   merchant_37           travel         purchase
# 6100  384.62      GBP  merchant_147            other       withdrawal
#
#      payment_method                                 location       ip_address  \
# 0            crypto     {'lat': 21.98258, 'lon': -68.405618}    89.112.47.139
# 1     bank_transfer  {'lat': 88.3596805, 'lon': -155.712054}   139.99.247.116
# 2        debit_card    {'lat': -0.509515, 'lon': -64.863057}    145.17.109.83
# 3            crypto   {'lat': 64.509113, 'lon': -108.162837}  206.118.169.198
# 4            paypal    {'lat': -76.32964, 'lon': -25.554481}  109.190.162.161
# ...             ...                                      ...              ...
# 6096     debit_card     {'lat': 39.389975, 'lon': 21.982878}    83.136.112.84
# 6097    credit_card  {'lat': 74.1238375, 'lon': -172.176932}     139.52.85.59
# 6098         paypal  {'lat': -67.274606, 'lon': -150.732247}     207.47.166.8
# 6099         crypto      {'lat': 7.77527, 'lon': -53.151409}    163.140.62.23
# 6100         crypto     {'lat': 63.4050175, 'lon': 0.828025}   134.140.162.20
#
#                                  device_info  \
# 0         {'os': 'iOS', 'browser': 'Chrome'}
# 1         {'os': 'Other', 'browser': 'Edge'}
# 2       {'os': 'Other', 'browser': 'Safari'}
# 3      {'os': 'Linux', 'browser': 'Firefox'}
# 4      {'os': 'Linux', 'browser': 'Firefox'}
# ...                                      ...
# 6096    {'os': 'macOS', 'browser': 'Safari'}
# 6097   {'os': 'Windows', 'browser': 'Opera'}
# 6098  {'os': 'Android', 'browser': 'Safari'}
# 6099     {'os': 'Linux', 'browser': 'Other'}
# 6100   {'os': 'Windows', 'browser': 'Opera'}
#
#                                              user_agent account_age_days  \
# 0     Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_8...             1377
# 1     Mozilla/5.0 (Android 4.4.1; Mobile; rv:15.0) G...              959
# 2     Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...              298
# 3     Mozilla/5.0 (X11; Linux x86_64; rv:1.9.5.20) G...              916
# 4     Opera/9.83.(X11; Linux x86_64; tt-RU) Presto/2...              851
# ...                                                 ...              ...
# 6096  Opera/8.46.(Windows NT 5.2; st-ZA) Presto/2.9....              684
# 6097  Opera/8.80.(X11; Linux x86_64; niu-NU) Presto/...              307
# 6098  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_1...              622
# 6099  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like M...              480
# 6100  Mozilla/5.0 (iPhone; CPU iPhone OS 4_3_5 like ...              183
#
#      cvv_provided billing_address_match is_fraud
# 0            True                  True        0
# 1            True                  True        0
# 2            True                  True        0
# 3            True                  True        0
# 4            True                  True        0
# ...           ...                   ...      ...
# 6096         True                  True        0
# 6097         True                  True        0
# 6098         True                  True        0
# 6099         True                  True        0
# 6100         True                  True        0
#
# [6101 rows x 17 columns]

# %%
import pickle
with open("../fastapi_app/river_model.pkl", "rb") as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pickle
#       2 with open("../fastapi_app/river_model.pkl", "rb") as f:
# ----> 3     model = pickle.load(f)
#
# AttributeError: Can't get attribute 'extract_device_info' on <module '__main__'>

# %%
model
# Out:
# Pipeline (
#   Select (
#     account_age_days
#     amount
#   ),
#   StandardScaler (
#     with_std=True
#   ),
#   LogisticRegression (
#     optimizer=SGD (
#       lr=Constant (
#         learning_rate=0.01
#       )
#     )
#     loss=Log (
#       weight_pos=1.
#       weight_neg=1.
#     )
#     l2=0.
#     l1=0.
#     intercept_init=0.
#     intercept_lr=Constant (
#       learning_rate=0.01
#     )
#     clip_gradient=1e+12
#     initializer=Zeros ()
#   )
# )

# %%
import river
dir(river)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'annotations',
#  'base',
#  'compose',
#  'covariance',
#  'linear_model',
#  'optim',
#  'preprocessing',
#  'proba',
#  'stats',
#  'utils']

# %%
dir(river.preprocessing)
# Out:
# ['AdaptiveStandardScaler',
#  'Binarizer',
#  'FeatureHasher',
#  'GaussianRandomProjector',
#  'LDA',
#  'MaxAbsScaler',
#  'MinMaxScaler',
#  'Normalizer',
#  'OneHotEncoder',
#  'OrdinalEncoder',
#  'PredClipper',
#  'PreviousImputer',
#  'RobustScaler',
#  'SparseRandomProjector',
#  'StandardScaler',
#  'StatImputer',
#  'TargetMinMaxScaler',
#  'TargetStandardScaler',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'annotations',
#  'feature_hasher',
#  'impute',
#  'lda',
#  'one_hot',
#  'ordinal',
#  'pred_clipper',
#  'random_projection',
#  'scale',
#  'scale_target']

# %%
from pprint import pprint
from river import datasets

dataset = datasets.Bikes()
model = river.preprocessing.OrdinalEncoder()

for i, (x, y) in enumerate(dataset):
    #pprint(x)
    #pprint(y)
    model.learn_one(x)
    model.transform_one(x)
    if i >= 10:
        break

print(model.categories)
# Out:
# defaultdict(<class 'dict'>, {'moment': {datetime.datetime(2016, 4, 1, 0, 0, 7): 1, datetime.datetime(2016, 4, 1, 0, 0, 16): 2, datetime.datetime(2016, 4, 1, 0, 0, 35): 3, datetime.datetime(2016, 4, 1, 0, 4, 50): 4, datetime.datetime(2016, 4, 1, 0, 5, 29): 5, datetime.datetime(2016, 4, 1, 0, 8, 18): 6, datetime.datetime(2016, 4, 1, 0, 9, 18): 7, datetime.datetime(2016, 4, 1, 0, 9, 25): 8, datetime.datetime(2016, 4, 1, 0, 9, 54): 9, datetime.datetime(2016, 4, 1, 0, 10, 9): 10, datetime.datetime(2016, 4, 1, 0, 10, 38): 11}, 'station': {'metro-canal-du-midi': 1, 'place-des-carmes': 2, 'place-esquirol': 3, 'pomme': 4, 'place-jeanne-darc': 5}, 'clouds': {75: 1}, 'description': {'light rain': 1}, 'humidity': {81: 1}, 'pressure': {1017.0: 1}, 'temperature': {6.54: 1}, 'wind': {9.3: 1}})

# %%
pprint(x)
# Out:
# {'clouds': 75,
#  'description': 'light rain',
#  'humidity': 81,
#  'moment': datetime.datetime(2016, 4, 1, 0, 10, 38),
#  'pressure': 1017.0,
#  'station': 'place-des-carmes',
#  'temperature': 6.54,
#  'wind': 9.3}

# %%
def extract_moment_features(x):
    x_ = x['moment']
    return {
        'year': x_.year,
        'month': x_.month,
        "day": x_.day,
        'hour': x_.hour,
        'minute': x_.minute,
        'second': x_.second,
        'weekday': x_.weekday(),
    }

pipe1 = river.compose.Select(
    "clouds",
    "humidity",
    "pressure",
    "temperature",
    "wind"
)
pipe2 = river.compose.Select(
    "description",
    "station"
)
pipe2 |= river.preprocessing.OrdinalEncoder()
pipe3 = river.compose.Select(
    "moment"
)
pipe3 |= river.compose.FuncTransformer(
    extract_moment_features,
)

transformer = pipe1 + pipe2 + pipe3
transformer.learn_one(x)
transformer.transform_one(x)
# Out:
# {'year': 2016,
#  'month': 4,
#  'day': 1,
#  'hour': 0,
#  'minute': 10,
#  'second': 38,
#  'weekday': 4,
#  'station': 1,
#  'description': 1,
#  'pressure': 1017.0,
#  'clouds': 75,
#  'wind': 9.3,
#  'temperature': 6.54,
#  'humidity': 81}

# %%
from pprint import pprint

x = {
    'transaction_id': 'ffd3d366-06e4-4ddb-894e-03876e893079', 
    'user_id': '61fa227e-d309-4ed0-b513-3cffa5526463', 
    'timestamp': '2025-04-17T19:52:06.994066+00:00', 
    'amount': 302.69, 
    'currency': 'BRL', 
    'merchant_id': 'merchant_65', 
    'product_category': 'luxury_items', 
    'transaction_type': 'deposit', 
    'payment_method': 'debit_card', 
    'location': {'lat': -68.4965105, 'lon': -153.515477}, 
    'ip_address': '169.235.63.28', 
    'device_info': {'os': 'Windows', 'browser': 'Opera'}, 
    'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 11.0) AppleWebKit/532.16.3 (KHTML, like Gecko) Version/4.1 Safari/532.16.3', 
    'account_age_days': 370, 
    'cvv_provided': True, 
    'billing_address_match': True, 
    'is_fraud': 0}

pprint(x)
# Out:
# {'account_age_days': 370,
#  'amount': 302.69,
#  'billing_address_match': True,
#  'currency': 'BRL',
#  'cvv_provided': True,
#  'device_info': {'browser': 'Opera', 'os': 'Windows'},
#  'ip_address': '169.235.63.28',
#  'is_fraud': 0,
#  'location': {'lat': -68.4965105, 'lon': -153.515477},
#  'merchant_id': 'merchant_65',
#  'payment_method': 'debit_card',
#  'product_category': 'luxury_items',
#  'timestamp': '2025-04-17T19:52:06.994066+00:00',
#  'transaction_id': 'ffd3d366-06e4-4ddb-894e-03876e893079',
#  'transaction_type': 'deposit',
#  'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 11.0) AppleWebKit/532.16.3 '
#                '(KHTML, like Gecko) Version/4.1 Safari/532.16.3',
#  'user_id': '61fa227e-d309-4ed0-b513-3cffa5526463'}

# %%
def extract_device_info(x):
    x_ = x['device_info']
    return {
        'os': x_['os'],
        'browser': x_['browser'],
    }

pipe1 = river.compose.Select(
    "amount",
    "account_age_days",
    "cvv_provided",
    "billing_address_match"
)
pipe2 = river.compose.Select(
    "currency",
    "merchant_id",
    "payment_method",
    "product_category",
    "transaction_type",
    "user_agent"
)
pipe2 |= river.preprocessing.OrdinalEncoder()
pipe3 = river.compose.Select(
    "device_info"
)
pipe3 |= river.compose.FuncTransformer(
    extract_device_info,
)
pipe3 |= river.preprocessing.OrdinalEncoder()
pipe = pipe1 + pipe2 + pipe3
#pipe.transform_one(x)
model = pipe | river.linear_model.LogisticRegression()

# %%
y_pred = model.predict_one(x)
model.learn_one(x, True)

# %%
y_pred
# Out:
# False

# %%
list(pipe.transform_one(x).keys())
# Out:
# ['os',
#  'browser',
#  'transaction_type',
#  'product_category',
#  'currency',
#  'merchant_id',
#  'user_agent',
#  'payment_method',
#  'amount',
#  'billing_address_match',
#  'cvv_provided',
#  'account_age_days']

# %%
print(model.debug_one(x))
# Out:
# 0. Input
# --------
# account_age_days: 370 (int)
# amount: 302.69000 (float)
# billing_address_match: True (bool)
# currency: BRL (str)
# cvv_provided: True (bool)
# device_info: {'os': 'Windows', 'browser': 'Opera'} (dict)
# ip_address: 169.235.63.28 (str)
# is_fraud: 0 (int)
# location: {'lat': -68.4965105, 'lon': -153.515477} (dict)
# merchant_id: merchant_65 (str)
# payment_method: debit_card (str)
# product_category: luxury_items (str)
# timestamp: 2025-04-17T19:52:06.994066+00:00 (str)
# transaction_id: ffd3d366-06e4-4ddb-894e-03876e893079 (str)
# transaction_type: deposit (str)
# user_agent: Mozilla/5.0 (Windows; U; Windows NT 11.0) AppleWebKit/532.16.3 (KHTML, like Gecko) Version/4.1 Safari/532.16.3 (str)
# user_id: 61fa227e-d309-4ed0-b513-3cffa5526463 (str)
#
# 1. Transformer union
# --------------------
#     1.0 Select
#     ----------
#     account_age_days: 370 (int)
#     amount: 302.69000 (float)
#     billing_address_match: True (bool)
#     cvv_provided: True (bool)
#
#     1.1 ['currency', 'merchant_id', 'payment_method', 'product_category', 'transaction_type', 'user_agent'] | OrdinalEncoder
#     ------------------------------------------------------------------------------------------------------------------------
#     currency: 1 (int)
#     merchant_id: 1 (int)
#     payment_method: 1 (int)
#     product_category: 1 (int)
#     transaction_type: 1 (int)
#     user_agent: 1 (int)
#
#     1.2 ['device_info'] | extract_device_info | OrdinalEncoder
#     ----------------------------------------------------------
#     browser: 1 (int)
#     os: 1 (int)
#
# account_age_days: 370 (int)
# amount: 302.69000 (float)
# billing_address_match: True (bool)
# browser: 1 (int)
# currency: 1 (int)
# cvv_provided: True (bool)
# merchant_id: 1 (int)
# os: 1 (int)
# payment_method: 1 (int)
# product_category: 1 (int)
# transaction_type: 1 (int)
# user_agent: 1 (int)
#
# 2. LogisticRegression
# ---------------------
#
# False: 0.00000
# True: 1

# %%
import river

dir(river)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'annotations',
#  'base',
#  'compose',
#  'covariance',
#  'datasets',
#  'linear_model',
#  'optim',
#  'preprocessing',
#  'proba',
#  'stats',
#  'stream',
#  'utils']

# %%
import river

river.compat.convert_river_to_sklearn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 3
#       1 import river
# ----> 3 river.compat.convert_river_to_sklearn
#
# AttributeError: module 'river.compat' has no attribute 'convert_river_to_sklearn'

# %%
from river import compose, preprocessing, linear_model

# Create a new model pipeline
pipe1 = compose.Select(
    "amount",
    "account_age_days",
    "cvv_provided",
    "billing_address_match"
)
pipe2 = compose.Select(
    "currency",
    "merchant_id",
    "payment_method",
    "product_category",
    "transaction_type",
    "user_agent"
)
pipe2 |= preprocessing.OrdinalEncoder()
pipe3 = compose.Select(
    "device_info"
)
pipe3 |= compose.FuncTransformer(
    extract_device_info,
)
pipe3 |= preprocessing.OrdinalEncoder()
pipe = pipe1 + pipe2 + pipe3
model = pipe | linear_model.LogisticRegression()

# %%
x = {
    'transaction_id': 'a8d5c400-48bc-483a-bc1f-c27d2ccf51d4', 
    'user_id': '1a8958be-7947-4e98-9843-cbf4aa15ad9a', 
    'timestamp': '2025-04-19T03:58:37.756061+00:00', 
    'amount': 220.3, 
    'currency': 'JPY', 
    'merchant_id': 'merchant_20', 
    'product_category': 'electronics', 
    'transaction_type': 'transfer', 
    'payment_method': 'bank_transfer', 
    'location': {'lat': -60.413132, 'lon': -167.638426}, 
    'ip_address': '201.227.163.12', 
    'device_info': {'os': 'Windows', 'browser': 'Safari'}, 
    'user_agent': 'Mozilla/5.0 (Windows NT 5.01) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/54.0.848.0 Safari/532.2', 
    'account_age_days': 1613, 
    'cvv_provided': True, 
    'billing_address_match': True, 
    'is_fraud': 0}
y = False

# %%
print(model)
# Out:
# ['account_age_days', 'amount', 'billing_address_match', 'cvv_provided'] + ['currency', 'merchant_id', 'payment_method', 'product_category', 'transaction_type', 'user_agent'] | OrdinalEncoder + ['device_info'] | extract_device_info | OrdinalEncoder | LogisticRegression

# %%
# Update the model
y_pred = model.predict_one(x)
model.learn_one(x, y)
# Update metrics if provided

# %%
print(model)
# Out:
# ['account_age_days', 'amount', 'billing_address_match', 'cvv_provided'] + ['currency', 'merchant_id', 'payment_method', 'product_category', 'transaction_type', 'user_agent'] | OrdinalEncoder + ['device_info'] | extract_device_info | OrdinalEncoder | LogisticRegression

# %%
dir(model)
# Out:
# ['_LEARN_UNSUPERVISED_DURING_PREDICT',
#  '__abstractmethods__',
#  '__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__ror__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_step',
#  '_get_params',
#  '_is_stochastic',
#  '_last_step',
#  '_memory_usage',
#  '_more_tags',
#  '_multiclass',
#  '_mutable_attributes',
#  '_raw_memory_usage',
#  '_repr_html_',
#  '_supervised',
#  '_tags',
#  '_transform_many',
#  '_transform_one',
#  '_unit_test_params',
#  '_unit_test_skips',
#  'clone',
#  'debug_one',
#  'forecast',
#  'learn_many',
#  'learn_one',
#  'mutate',
#  'predict_many',
#  'predict_one',
#  'predict_proba_many',
#  'predict_proba_one',
#  'score_one',
#  'steps',
#  'transform_many',
#  'transform_one']

# %%
model.steps.keys()
# Out:
# odict_keys(['TransformerUnion', 'LogisticRegression'])

# %%
estimator_name = list(model.steps.keys())[-1]
estimator_name
# Out:
# 'LogisticRegression'

# %%
estimator = model.steps[estimator_name]
estimator
# Out:
# LogisticRegression (
#   optimizer=SGD (
#     lr=Constant (
#       learning_rate=0.01
#     )
#   )
#   loss=Log (
#     weight_pos=1.
#     weight_neg=1.
#   )
#   l2=0.
#   l1=0.
#   intercept_init=0.
#   intercept_lr=Constant (
#     learning_rate=0.01
#   )
#   clip_gradient=1e+12
#   initializer=Zeros ()
# )

# %%
transformer_union_name = list(model.steps.keys())[-2]
transformer_union = model.steps[transformer_union_name]

# %%
transformer_dict = [
    (transformer_name, transformer) 
    for transformer_name, transformer 
    in transformer_union.transformers.items()]
transformer_dict[1][1].steps["OrdinalEncoder"].categories
# Out:
# defaultdict(dict,
#             {'transaction_type': {'transfer': 1},
#              'merchant_id': {'merchant_20': 1},
#              'payment_method': {'bank_transfer': 1},
#              'user_agent': {'Mozilla/5.0 (Windows NT 5.01) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/54.0.848.0 Safari/532.2': 1},
#              'currency': {'JPY': 1},
#              'product_category': {'electronics': 1}})

# %%
if isinstance(estimator, linear_model.LogisticRegression):
    print(dict(estimator.weights))
# Out:
# {'os': -0.005, 'browser': -0.005, 'transaction_type': -0.005, 'merchant_id': -0.005, 'payment_method': -0.005, 'user_agent': -0.005, 'currency': -0.005, 'product_category': -0.005, 'billing_address_match': -0.005, 'amount': -1.1015000000000001, 'cvv_provided': -0.005, 'account_age_days': -8.065}

# %%
from river import compat

# We make the Pipeline compatible with sklearn
model = compat.river_to_sklearn.convert_river_to_sklearn(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 from river import compat
#       3 # We make the Pipeline compatible with sklearn
# ----> 4 model = compat.river_to_sklearn.convert_river_to_sklearn(model)
#
# File ~/Workbench/COELHORealTime/tests/.venv/lib/python3.12/site-packages/river/compat/river_to_sklearn.py:63, in convert_river_to_sklearn(estimator)
#      53 """Wraps a river estimator to make it compatible with scikit-learn.
#      54
#      55 Parameters
#    (...)     58
#      59 """
#      61 if isinstance(estimator, compose.Pipeline):
#      62     return pipeline.Pipeline(
# ---> 63         [(name, convert_river_to_sklearn(step)) for name, step in estimator.steps.items()]
#      64     )
#      66 wrappers = [
#      67     (base.Classifier, River2SKLClassifier),
#      68     (base.Clusterer, River2SKLClusterer),
#      69     (base.Regressor, River2SKLRegressor),
#      70     (base.Transformer, River2SKLTransformer),
#      71 ]
#      73 for base_type, wrapper in wrappers:
#
# File ~/Workbench/COELHORealTime/tests/.venv/lib/python3.12/site-packages/river/compat/river_to_sklearn.py:76, in convert_river_to_sklearn(estimator)
#      74     if isinstance(estimator, base_type):
#      75         obj = wrapper(estimator)
# ---> 76         obj.instance_ = copy.deepcopy(estimator)
#      77         return obj
#      79 raise ValueError("Couldn't find an appropriate wrapper")
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:285, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     283     for key, value in dictiter:
#     284         key = deepcopy(key, memo)
# --> 285         value = deepcopy(value, memo)
#     286         y[key] = value
#     287 else:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:259, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     257 if state is not None:
#     258     if deep:
# --> 259         state = deepcopy(state, memo)
#     260     if hasattr(y, '__setstate__'):
#     261         y.__setstate__(state)
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:136, in deepcopy(x, memo, _nil)
#     134 copier = _deepcopy_dispatch.get(cls)
#     135 if copier is not None:
# --> 136     y = copier(x, memo)
#     137 else:
#     138     if issubclass(cls, type):
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:221, in _deepcopy_dict(x, memo, deepcopy)
#     219 memo[id(x)] = y
#     220 for key, value in x.items():
# --> 221     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     222 return y
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:162, in deepcopy(x, memo, _nil)
#     160                 y = x
#     161             else:
# --> 162                 y = _reconstruct(x, memo, *rv)
#     164 # If is its own copy, don't memoize.
#     165 if y is not x:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:285, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     283     for key, value in dictiter:
#     284         key = deepcopy(key, memo)
# --> 285         value = deepcopy(value, memo)
#     286         y[key] = value
#     287 else:
#
# File ~/snap/code/187/.local/share/uv/python/cpython-3.12.9-linux-x86_64-gnu/lib/python3.12/copy.py:151, in deepcopy(x, memo, _nil)
#     149 reductor = getattr(x, "__reduce_ex__", None)
#     150 if reductor is not None:
# --> 151     rv = reductor(4)
#     152 else:
#     153     reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle 'generator' object

# %%
# Save model periodically
with open("sklearn_model_test.pkl", 'wb') as f:
    pickle.dump(model, f)

# %%
# We make the Pipeline compatible with sklearn
model = compat.river_to_sklearn.convert_river_to_sklearn(model)

# %%
type(model)
# Out:
# sklearn.pipeline.Pipeline

# %%
import pickle
with open("../fastapi_app/sklearn_model.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
from river import compat

# %%
compat.sklearn_to_river
# Out:
# <module 'river.compat.sklearn_to_river' from '/home/rafaelcoelho/Workbench/COELHORealTime/tests/.venv/lib/python3.12/site-packages/river/compat/sklearn_to_river.py'>
