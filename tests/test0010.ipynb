# %%
import json

# %%
with open("../fastapi_app/data/cluster_feature_counts.json", 'r') as f:
    data = json.load(f)

# %%
clusters = list(data.keys())
clusters
# Out:
# ['2', '3', '1', '0']

# %%
{
    x: data[x]["event_type"]
    for x in clusters
}
# Out:
# {'2': {'page_view': 1070,
#   'search': 307,
#   'purchase': 96,
#   'add_to_cart': 493,
#   'leave_review': 32},
#  '3': {'page_view': 117,
#   'add_to_cart': 55,
#   'search': 29,
#   'purchase': 13,
#   'leave_review': 5},
#  '1': {'page_view': 1004,
#   'purchase': 81,
#   'add_to_cart': 409,
#   'search': 259,
#   'leave_review': 28},
#  '0': {'search': 3}}
