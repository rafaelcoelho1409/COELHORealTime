# %%
from river import metrics

# %%
dir(metrics)
# Out:
# ['Accuracy',
#  'AdjustedMutualInfo',
#  'AdjustedRand',
#  'BalancedAccuracy',
#  'ClassificationReport',
#  'CohenKappa',
#  'Completeness',
#  'ConfusionMatrix',
#  'CrossEntropy',
#  'F1',
#  'FBeta',
#  'FowlkesMallows',
#  'GeometricMean',
#  'Homogeneity',
#  'Jaccard',
#  'LogLoss',
#  'MAE',
#  'MAPE',
#  'MCC',
#  'MSE',
#  'MacroF1',
#  'MacroFBeta',
#  'MacroJaccard',
#  'MacroPrecision',
#  'MacroRecall',
#  'MicroF1',
#  'MicroFBeta',
#  'MicroJaccard',
#  'MicroPrecision',
#  'MicroRecall',
#  'MultiFBeta',
#  'MutualInfo',
#  'NormalizedMutualInfo',
#  'Precision',
#  'R2',
#  'RMSE',
#  'RMSLE',
#  'ROCAUC',
#  'Rand',
#  'Recall',
#  'RollingROCAUC',
#  'SMAPE',
#  'Silhouette',
#  'VBeta',
#  'WeightedF1',
#  'WeightedFBeta',
#  'WeightedJaccard',
#  'WeightedPrecision',
#  'WeightedRecall',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'accuracy',
# ...

# %%
import pandas as pd
data = pd.read_pickle('river_data.pkl')
data.shape
# Out:
# (158, 17)
