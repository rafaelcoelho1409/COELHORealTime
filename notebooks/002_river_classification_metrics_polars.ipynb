# %%
import polars as pl
import orjson
import datetime as dt
from pprint import pprint
from typing import Any, Dict, Hashable, Optional, List
import tqdm
from river import (
    base,
    compose,
    metrics,
    drift,
    forest,
    cluster,
    preprocessing,
    time_series,
    linear_model,
)

# %%
MINIO_HOST = "localhost"
MINIO_ENDPOINT = f"http://{MINIO_HOST}:9000"
MINIO_ACCESS_KEY = "minioadmin"
MINIO_SECRET_KEY = "minioadmin123"
PROJECT_NAME = "Transaction Fraud Detection"

# %%
DELTA_STORAGE_OPTIONS = {
    "AWS_ENDPOINT_URL": MINIO_ENDPOINT,
    "AWS_ACCESS_KEY_ID": MINIO_ACCESS_KEY,
    "AWS_SECRET_ACCESS_KEY": MINIO_SECRET_KEY,
    "AWS_REGION": "us-east-1",
    "AWS_S3_ALLOW_UNSAFE_RENAME": "true",
    "AWS_ALLOW_HTTP": "true",
}

# %%
DELTA_PATHS = {
    "Transaction Fraud Detection": "s3://lakehouse/delta/transaction_fraud_detection",
    "Estimated Time of Arrival": "s3://lakehouse/delta/estimated_time_of_arrival",
    "E-Commerce Customer Interactions": "s3://lakehouse/delta/e_commerce_customer_interactions",
    "Sales Forecasting": "s3://lakehouse/delta/sales_forecasting",
}

# %%
delta_path = DELTA_PATHS.get("Transaction Fraud Detection")

# %%
lf = pl.scan_delta(
    delta_path, 
    storage_options = DELTA_STORAGE_OPTIONS)

# %%
sql = pl.SQLContext()
sql.register("data", lf)
# Out:
# <SQLContext [tables:1] at 0x7f7176e1cad0>

# %%
result = sql.execute("SELECT * FROM data LIMIT 1000").collect()
result
# Out:
# shape: (1_000, 17)
# ┌────────────┬────────────┬────────────┬────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ transactio ┆ user_id    ┆ timestamp  ┆ amount ┆ … ┆ account_a ┆ cvv_provi ┆ billing_a ┆ is_fraud │
# │ n_id       ┆ ---        ┆ ---        ┆ ---    ┆   ┆ ge_days   ┆ ded       ┆ ddress_ma ┆ ---      │
# │ ---        ┆ str        ┆ str        ┆ f64    ┆   ┆ ---       ┆ ---       ┆ tch       ┆ i32      │
# │ str        ┆            ┆            ┆        ┆   ┆ i32       ┆ bool      ┆ ---       ┆          │
# │            ┆            ┆            ┆        ┆   ┆           ┆           ┆ bool      ┆          │
# ╞════════════╪════════════╪════════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ee583be0-c ┆ 1b02783e-4 ┆ 2026-01-13 ┆ 35.62  ┆ … ┆ 657       ┆ true      ┆ true      ┆ 0        │
# │ 39d-4c17-a ┆ 92a-4820-9 ┆ T22:08:26. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ b99-9e941b ┆ d44-46a343 ┆ 555237+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 6ed1848c-5 ┆ 92294c5a-2 ┆ 2026-01-13 ┆ 316.91 ┆ … ┆ 56        ┆ true      ┆ true      ┆ 0        │
# │ f04-40bb-a ┆ 6ed-429d-9 ┆ T22:08:26. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 506-2faf06 ┆ ddd-e1f2ad ┆ 927459+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ a196f742-7 ┆ c015b552-6 ┆ 2026-01-13 ┆ 411.43 ┆ … ┆ 1253      ┆ true      ┆ true      ┆ 0        │
# │ 6e7-4db0-a ┆ 839-4283-a ┆ T22:08:27. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 56a-70f53e ┆ 90f-a72c1a ┆ 188999+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ eecc2d9c-e ┆ 511f44f9-a ┆ 2026-01-13 ┆ 273.37 ┆ … ┆ 46        ┆ true      ┆ true      ┆ 0        │
# │ aed-47e5-8 ┆ 097-4ba4-8 ┆ T22:08:27. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ da5-948cbf ┆ 559-0ce40a ┆ 666879+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 341820da-3 ┆ 61ced3b8-2 ┆ 2026-01-13 ┆ 416.58 ┆ … ┆ 648       ┆ true      ┆ true      ┆ 0        │
# │ 31e-4e04-9 ┆ b69-4816-9 ┆ T22:08:28. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 39b-8de4b1 ┆ e5c-a15af8 ┆ 087394+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆ …      ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ b2f90039-1 ┆ e8541af0-4 ┆ 2026-01-13 ┆ 442.4  ┆ … ┆ 166       ┆ true      ┆ true      ┆ 0        │
# │ 8aa-413d-a ┆ 95b-4683-a ┆ T22:07:03. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 875-147e95 ┆ 0f8-fad11d ┆ 008008+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ f0c15566-2 ┆ d56e3b7b-8 ┆ 2026-01-13 ┆ 806.9  ┆ … ┆ 1464      ┆ true      ┆ true      ┆ 1        │
# │ d13-404d-a ┆ e83-49d8-a ┆ T22:07:03. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 488-ba4e75 ┆ e52-5ad2fd ┆ 295945+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 39dce626-6 ┆ 38d5fd98-7 ┆ 2026-01-13 ┆ 91.3   ┆ … ┆ 1769      ┆ true      ┆ true      ┆ 0        │
# │ 94f-40e0-8 ┆ d9b-4810-9 ┆ T22:07:03. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 6c5-faf9f6 ┆ fbf-e071e8 ┆ 428810+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 258a812c-5 ┆ 6b02a5fc-1 ┆ 2026-01-13 ┆ 368.3  ┆ … ┆ 1059      ┆ true      ┆ true      ┆ 0        │
# │ 37f-44d3-8 ┆ 789-4e3f-a ┆ T22:07:03. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ d88-74f1c5 ┆ 3af-6c63f3 ┆ 585432+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# │ 0b519282-6 ┆ a6499e73-7 ┆ 2026-01-13 ┆ 199.41 ┆ … ┆ 1477      ┆ true      ┆ true      ┆ 0        │
# │ db7-42fb-a ┆ 01d-4aa3-9 ┆ T22:07:03. ┆        ┆   ┆           ┆           ┆           ┆          │
# │ f36-ca5e00 ┆ f5b-3e9ff0 ┆ 908668+00: ┆        ┆   ┆           ┆           ┆           ┆          │
# │ …          ┆ …          ┆ …          ┆        ┆   ┆           ┆           ┆           ┆          │
# └────────────┴────────────┴────────────┴────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
samples = result.to_dicts()
samples
# Out:
# [{'transaction_id': 'ee583be0-c39d-4c17-ab99-9e941b0a7606',
#   'user_id': '1b02783e-492a-4820-9d44-46a343e6420a',
#   'timestamp': '2026-01-13T22:08:26.555237+00:00',
#   'amount': 35.62,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_53',
#   'product_category': 'digital_goods',
#   'transaction_type': 'deposit',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-3.685515,"lon":61.184191}',
#   'ip_address': '157.23.223.51',
#   'device_info': '{"os":"Windows","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows 98; Trident/3.0)',
#   'account_age_days': 657,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '6ed1848c-5f04-40bb-a506-2faf06edd832',
#   'user_id': '92294c5a-26ed-429d-9ddd-e1f2ada5d08f',
#   'timestamp': '2026-01-13T22:08:26.927459+00:00',
#   'amount': 316.91,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_68',
#   'product_category': 'services',
#   'transaction_type': 'payment',
#   'payment_method': 'crypto',
#   'location': '{"lat":-89.3953295,"lon":-132.807133}',
#   'ip_address': '132.39.71.49',
#   'device_info': '{"os":"macOS","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (Windows 95; gez-ET; rv:1.9.0.20) Gecko/9443-07-30 16:48:14.419708 Firefox/3.6.9',
#   'account_age_days': 56,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'a196f742-76e7-4db0-a56a-70f53e07ba3d',
#   'user_id': 'c015b552-6839-4283-a90f-a72c1a00e4a6',
#   'timestamp': '2026-01-13T22:08:27.188999+00:00',
#   'amount': 411.43,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_82',
#   'product_category': 'travel',
#   'transaction_type': 'transfer',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-7.958436,"lon":-79.050257}',
#   'ip_address': '130.181.12.16',
#   'device_info': '{"os":"Windows","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 4.0) AppleWebKit/534.2 (KHTML, like Gecko) Chrome/13.0.821.0 Safari/534.2',
#   'account_age_days': 1253,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'eecc2d9c-eaed-47e5-8da5-948cbf1e3518',
#   'user_id': '511f44f9-a097-4ba4-8559-0ce40afb32b7',
#   'timestamp': '2026-01-13T22:08:27.666879+00:00',
#   'amount': 273.37,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_177',
#   'product_category': 'gambling',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":52.5498685,"lon":-132.015068}',
#   'ip_address': '91.149.136.147',
#   'device_info': '{"os":"Windows","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 5.2; Trident/5.1)',
#   'account_age_days': 46,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '341820da-331e-4e04-939b-8de4b1a8807d',
#   'user_id': '61ced3b8-2b69-4816-9e5c-a15af85cc830',
#   'timestamp': '2026-01-13T22:08:28.087394+00:00',
#   'amount': 416.58,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_122',
#   'product_category': 'other',
#   'transaction_type': 'purchase',
#   'payment_method': 'paypal',
#   'location': '{"lat":-43.5955175,"lon":95.163055}',
#   'ip_address': '157.170.210.33',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/3.1)',
#   'account_age_days': 648,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'fcc7ea5a-7c37-4cb7-b0b0-6be0e7e21ceb',
#   'user_id': 'c36f2e82-81e5-4569-8001-2db6147089df',
#   'timestamp': '2026-01-13T22:08:28.573779+00:00',
#   'amount': 41.56,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_72',
#   'product_category': 'other',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":4.6606215,"lon":-38.334494}',
#   'ip_address': '92.224.210.106',
#   'device_info': '{"os":"macOS","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 4.0; ts-ZA; rv:1.9.1.20) Gecko/3299-09-17 17:38:02.488647 Firefox/3.8',
#   'account_age_days': 361,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '0c50a878-f587-49e0-bef9-1b20e5ceed02',
#   'user_id': '77770231-8d7b-4c88-83b1-6de0509d7c0d',
#   'timestamp': '2026-01-13T22:08:29.009605+00:00',
#   'amount': 354.68,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_110',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":14.360641,"lon":-79.251127}',
#   'ip_address': '102.185.58.148',
#   'device_info': '{"os":"Android","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like Mac OS X; st-ZA) AppleWebKit/534.49.1 (KHTML, like Gecko) Version/4.0.5 Mobile/8B119 Safari/6534.49.1',
#   'account_age_days': 519,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '3bc37340-533d-4eab-a7ce-16379f5b4d24',
#   'user_id': 'efdc17c8-0154-4a40-a98a-a12d90a70063',
#   'timestamp': '2026-01-13T22:08:29.469131+00:00',
#   'amount': 370.2,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_178',
#   'product_category': 'services',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'crypto',
#   'location': '{"lat":16.5643105,"lon":-45.346175}',
#   'ip_address': '32.103.216.128',
#   'device_info': '{"os":"macOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.1)',
#   'account_age_days': 1142,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'ed009af7-887b-434e-b134-c5b3c628c258',
#   'user_id': '68534775-769e-4b8e-8da1-1f76567ac2d8',
#   'timestamp': '2026-01-13T22:08:29.921661+00:00',
#   'amount': 164.35,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_8',
#   'product_category': 'clothing',
#   'transaction_type': 'payment',
#   'payment_method': 'paypal',
#   'location': '{"lat":-34.434157,"lon":63.716173}',
#   'ip_address': '195.66.30.209',
#   'device_info': '{"os":"Windows","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_6 rv:4.0; th-TH) AppleWebKit/531.34.6 (KHTML, like Gecko) Version/4.0.3 Safari/531.34.6',
#   'account_age_days': 1199,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '45e2ffaf-68a9-46a0-a777-43b23d19e9d9',
#   'user_id': '065f7051-a4ed-424b-b281-84b61a8263cd',
#   'timestamp': '2026-01-13T22:08:30.143915+00:00',
#   'amount': 92.49,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_56',
#   'product_category': 'groceries',
#   'transaction_type': 'purchase',
#   'payment_method': 'debit_card',
#   'location': '{"lat":61.999303,"lon":124.053519}',
#   'ip_address': '69.168.244.218',
#   'device_info': '{"os":"Windows","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows CE; Trident/4.1)',
#   'account_age_days': 673,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '02812416-1b34-4d16-8777-8d1a7d0ea1e2',
#   'user_id': 'b1a11fd6-f939-47bf-9dce-d995dc3db073',
#   'timestamp': '2026-01-13T22:08:30.403801+00:00',
#   'amount': 424.06,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_14',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":34.0237295,"lon":43.8805}',
#   'ip_address': '101.104.251.5',
#   'device_info': '{"os":"Android","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/16.0.868.0 Safari/535.1',
#   'account_age_days': 53,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9de7bca4-3835-4659-866c-ff0be3aa7bd0',
#   'user_id': '1eb0255f-df87-48bc-a20c-c75c0adc6c1a',
#   'timestamp': '2026-01-13T22:08:30.731903+00:00',
#   'amount': 384.38,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_175',
#   'product_category': 'gambling',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":72.613373,"lon":-122.414088}',
#   'ip_address': '172.231.145.31',
#   'device_info': '{"os":"iOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPod; U; CPU iPhone OS 4_1 like Mac OS X; is-IS) AppleWebKit/533.27.5 (KHTML, like Gecko) Version/3.0.5 Mobile/8B117 Safari/6533.27.5',
#   'account_age_days': 150,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'c5a06613-25a9-484d-a429-b3b5e83cd535',
#   'user_id': '04e3e779-806e-4fdc-a5e4-db759036d4c2',
#   'timestamp': '2026-01-13T22:08:31.193686+00:00',
#   'amount': 16.83,
#   'currency': 'USD',
#   'merchant_id': 'merchant_196',
#   'product_category': 'services',
#   'transaction_type': 'payment',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-13.164207,"lon":61.090882}',
#   'ip_address': '14.48.17.198',
#   'device_info': '{"os":"macOS","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (Windows 98; Win 9x 4.90; bn-IN; rv:1.9.1.20) Gecko/2133-03-26 00:47:41.002927 Firefox/5.0',
#   'account_age_days': 1575,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '820ff8ab-f75b-4a37-a15d-03633e67b44c',
#   'user_id': '17765b5e-764f-4510-a4c7-0529ebaddcef',
#   'timestamp': '2026-01-13T22:08:31.572822+00:00',
#   'amount': 140.56,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_145',
#   'product_category': 'other',
#   'transaction_type': 'payment',
#   'payment_method': 'debit_card',
#   'location': '{"lat":32.005054,"lon":76.41375}',
#   'ip_address': '212.61.140.55',
#   'device_info': '{"os":"macOS","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (iPad; CPU iPad OS 12_4_4 like Mac OS X) AppleWebKit/535.2 (KHTML, like Gecko) FxiOS/18.8o3932.0 Mobile/98I998 Safari/535.2',
#   'account_age_days': 1127,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'ba66f1ff-022c-48fb-96c4-942accf0e7a6',
#   'user_id': '249729c3-6e1f-41f2-bbb4-c714f4136525',
#   'timestamp': '2026-01-13T22:08:32.024234+00:00',
#   'amount': 209.47,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_120',
#   'product_category': 'other',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'paypal',
#   'location': '{"lat":56.6704295,"lon":-14.007787}',
#   'ip_address': '153.169.67.139',
#   'device_info': '{"os":"Windows","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 5.0) AppleWebKit/531.2 (KHTML, like Gecko) Chrome/62.0.839.0 Safari/531.2',
#   'account_age_days': 242,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'a9f30a31-60d4-4d3d-89f9-eea4fffe4cdb',
#   'user_id': '513cf168-a0a4-4e61-9fd3-23882860a020',
#   'timestamp': '2026-01-13T22:08:32.105158+00:00',
#   'amount': 281.53,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_38',
#   'product_category': 'gambling',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":22.9983955,"lon":-56.726263}',
#   'ip_address': '195.152.252.209',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_11_8; rv:1.9.4.20) Gecko/6091-07-31 03:30:17.217255 Firefox/3.6.7',
#   'account_age_days': 1585,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '23589571-4023-4545-96da-d4fc47035824',
#   'user_id': '5410f639-79a8-42a4-b9db-676e5c0b756d',
#   'timestamp': '2026-01-13T22:08:32.296337+00:00',
#   'amount': 5.49,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_172',
#   'product_category': 'travel',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-21.8488525,"lon":141.570442}',
#   'ip_address': '68.197.123.225',
#   'device_info': '{"os":"Android","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_7_7 like Mac OS X) AppleWebKit/532.1 (KHTML, like Gecko) CriOS/46.0.807.0 Mobile/62P355 Safari/532.1',
#   'account_age_days': 1022,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9bc92047-79ef-4183-b18e-d40142a1132b',
#   'user_id': '12240e61-559c-4bee-bcf8-7977d30bf004',
#   'timestamp': '2026-01-13T22:08:32.562023+00:00',
#   'amount': 389.89,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_105',
#   'product_category': 'groceries',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'crypto',
#   'location': '{"lat":-89.746949,"lon":94.347759}',
#   'ip_address': '152.117.197.4',
#   'device_info': '{"os":"iOS","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_2) AppleWebKit/536.2 (KHTML, like Gecko) Chrome/31.0.808.0 Safari/536.2',
#   'account_age_days': 1571,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '4654a570-6b68-4e3e-b408-3dbe72be5901',
#   'user_id': '4bf8af1e-a302-4d7b-80fb-5a7171afdbae',
#   'timestamp': '2026-01-13T22:08:32.898242+00:00',
#   'amount': 430.77,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_14',
#   'product_category': 'groceries',
#   'transaction_type': 'purchase',
#   'payment_method': 'debit_card',
#   'location': '{"lat":37.1514175,"lon":163.868223}',
#   'ip_address': '85.131.148.77',
#   'device_info': '{"os":"Windows","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows 98; Trident/5.0)',
#   'account_age_days': 1197,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'bf5aa9bb-bd3e-4758-b250-fc47f87c54ef',
#   'user_id': '817f8fd0-5bab-4040-9016-1db5eeecb1e6',
#   'timestamp': '2026-01-13T22:08:33.382715+00:00',
#   'amount': 388.78,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_19',
#   'product_category': 'travel',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":-16.3458655,"lon":62.347543}',
#   'ip_address': '177.135.195.13',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 11.0; Trident/5.1)',
#   'account_age_days': 107,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'e05186c6-6361-4a50-a590-3bc1cd72a446',
#   'user_id': '191946b8-8d0b-42e0-886c-edd7036e6882',
#   'timestamp': '2026-01-13T22:08:33.932513+00:00',
#   'amount': 43.97,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_199',
#   'product_category': 'clothing',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-51.8914535,"lon":75.580567}',
#   'ip_address': '29.69.99.185',
#   'device_info': '{"os":"Windows","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; PPC Mac OS X 10_6_6; rv:1.9.4.20) Gecko/2261-02-06 07:01:36.303791 Firefox/3.6.18',
#   'account_age_days': 99,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '75774bbc-df47-47fa-b26a-b505b12a998a',
#   'user_id': '88019753-841f-43f1-bfec-96f26dec5647',
#   'timestamp': '2026-01-13T22:08:34.278899+00:00',
#   'amount': 314.83,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_38',
#   'product_category': 'travel',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-7.8362495,"lon":-13.992479}',
#   'ip_address': '39.255.215.81',
#   'device_info': '{"os":"iOS","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.0) AppleWebKit/533.14.1 (KHTML, like Gecko) Version/4.0.4 Safari/533.14.1',
#   'account_age_days': 1213,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '6e81c7d3-5b70-4c17-adf2-434eb4803251',
#   'user_id': '88bc3256-e898-475d-a547-634ed07078eb',
#   'timestamp': '2026-01-13T22:08:34.347854+00:00',
#   'amount': 23.54,
#   'currency': 'USD',
#   'merchant_id': 'merchant_112',
#   'product_category': 'luxury_items',
#   'transaction_type': 'payment',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-41.7178945,"lon":-155.878118}',
#   'ip_address': '181.120.46.138',
#   'device_info': '{"os":"Android","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_0 rv:4.0; lv-LV) AppleWebKit/535.33.3 (KHTML, like Gecko) Version/4.1 Safari/535.33.3',
#   'account_age_days': 1489,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '43340a18-c15e-4f19-a25f-99fbc51cbf83',
#   'user_id': '2d298bb8-8c7a-4adc-a98f-d0f930e7ad6f',
#   'timestamp': '2026-01-13T22:08:34.686190+00:00',
#   'amount': 324.38,
#   'currency': 'USD',
#   'merchant_id': 'merchant_183',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":66.803465,"lon":-139.388564}',
#   'ip_address': '42.49.167.93',
#   'device_info': '{"os":"macOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.0) AppleWebKit/532.3.3 (KHTML, like Gecko) Version/4.0.3 Safari/532.3.3',
#   'account_age_days': 1039,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '931a7fa0-545e-4de8-8c63-94782aa75909',
#   'user_id': '99d3bcd1-f342-4738-af55-242e70bcb875',
#   'timestamp': '2026-01-13T22:08:34.974801+00:00',
#   'amount': 256.07,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_116',
#   'product_category': 'groceries',
#   'transaction_type': 'purchase',
#   'payment_method': 'crypto',
#   'location': '{"lat":6.2286925,"lon":-96.471117}',
#   'ip_address': '179.196.144.81',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Opera/8.53.(Windows CE; ht-HT) Presto/2.9.180 Version/10.00',
#   'account_age_days': 193,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'd73b0039-5895-4ad5-98e3-fb8f20001cb0',
#   'user_id': '2c0d83fa-23a7-4417-868a-98cea437c068',
#   'timestamp': '2026-01-13T22:08:35.466721+00:00',
#   'amount': 131.11,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_115',
#   'product_category': 'groceries',
#   'transaction_type': 'deposit',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-44.6541965,"lon":80.677742}',
#   'ip_address': '172.133.95.8',
#   'device_info': '{"os":"Linux","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 5.0; Trident/4.1)',
#   'account_age_days': 1129,
#   'cvv_provided': False,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9dec7c98-b124-4c81-a7a2-054661f75dc5',
#   'user_id': 'd52f27de-3b52-4353-b90c-899e514d555b',
#   'timestamp': '2026-01-13T22:08:35.687393+00:00',
#   'amount': 237.89,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_18',
#   'product_category': 'services',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":-89.9802255,"lon":-40.637655}',
#   'ip_address': '88.121.6.27',
#   'device_info': '{"os":"Windows","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 4.0) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/25.0.852.0 Safari/532.2',
#   'account_age_days': 89,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '17d2f229-f7be-4b2c-9f03-e1561cd32eda',
#   'user_id': '19fedb1f-d8c8-474d-8196-6703bd42f342',
#   'timestamp': '2026-01-13T22:08:36.010750+00:00',
#   'amount': 422.09,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_106',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-34.6742575,"lon":27.894205}',
#   'ip_address': '96.33.6.22',
#   'device_info': '{"os":"Windows","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7_1 rv:2.0; fa-IR) AppleWebKit/531.41.2 (KHTML, like Gecko) Version/4.0.2 Safari/531.41.2',
#   'account_age_days': 17,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '49d5b1d7-6bd0-4f52-835d-4627f5fedf28',
#   'user_id': 'f83507cb-a46e-4d21-8784-b20e9b9b3cdd',
#   'timestamp': '2026-01-13T22:08:36.334623+00:00',
#   'amount': 463.06,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_158',
#   'product_category': 'electronics',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":63.674108,"lon":164.585145}',
#   'ip_address': '36.1.159.97',
#   'device_info': '{"os":"iOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows CE; Trident/4.0)',
#   'account_age_days': 947,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9b6ade7b-c03b-4074-bf15-49a71663fea8',
#   'user_id': 'f94fa3d6-a9b8-4927-af1b-ba3c2694dc13',
#   'timestamp': '2026-01-13T22:08:36.769878+00:00',
#   'amount': 69.33,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_89',
#   'product_category': 'travel',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":-81.114666,"lon":137.315466}',
#   'ip_address': '163.26.133.63',
#   'device_info': '{"os":"iOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_5_5 rv:6.0; mhr-RU) AppleWebKit/531.6.3 (KHTML, like Gecko) Version/4.0.4 Safari/531.6.3',
#   'account_age_days': 820,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'f79fd66e-b4f8-4b3e-9c4d-d411cf834394',
#   'user_id': 'e16eb31d-36a9-415d-8c1e-71abcb5d084a',
#   'timestamp': '2026-01-13T22:08:36.989415+00:00',
#   'amount': 332.71,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_3',
#   'product_category': 'other',
#   'transaction_type': 'payment',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-52.3175255,"lon":90.714223}',
#   'ip_address': '86.178.109.127',
#   'device_info': '{"os":"macOS","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 10.0; Trident/3.0)',
#   'account_age_days': 1743,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'a2a1ce24-ace5-429b-bda9-de54ebdd4ed2',
#   'user_id': '19d995a5-0e21-4ce9-a8e0-f2a5f22aaaf7',
#   'timestamp': '2026-01-13T22:08:37.476077+00:00',
#   'amount': 454.27,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_117',
#   'product_category': 'groceries',
#   'transaction_type': 'payment',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":10.037284,"lon":-112.692274}',
#   'ip_address': '162.239.245.87',
#   'device_info': '{"os":"iOS","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/531.0 (KHTML, like Gecko) Chrome/25.0.809.0 Safari/531.0',
#   'account_age_days': 1811,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '73a5bd0e-148e-40e3-986f-17cf888a6430',
#   'user_id': '18d09362-c52c-4f4a-a04d-19e7d3758650',
#   'timestamp': '2026-01-13T22:08:37.733023+00:00',
#   'amount': 97.18,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_170',
#   'product_category': 'gambling',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":66.8250945,"lon":-119.970215}',
#   'ip_address': '48.162.238.62',
#   'device_info': '{"os":"Windows","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 17_4 like Mac OS X) AppleWebKit/534.0 (KHTML, like Gecko) FxiOS/11.1e4287.0 Mobile/54V855 Safari/534.0',
#   'account_age_days': 336,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '4cbdca72-3f46-40e1-b0ba-a7518d873c84',
#   'user_id': 'ae7e45bf-f9f7-43f0-b8ae-c5e7b4d1ec06',
#   'timestamp': '2026-01-13T22:08:38.188047+00:00',
#   'amount': 18.87,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_125',
#   'product_category': 'clothing',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":82.018291,"lon":-114.42085}',
#   'ip_address': '109.88.121.132',
#   'device_info': '{"os":"Other","browser":"Safari"}',
#   'user_agent': 'Opera/9.99.(X11; Linux i686; szl-PL) Presto/2.9.163 Version/12.00',
#   'account_age_days': 282,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '82f2453d-7086-4804-a12b-1b0b50d86b18',
#   'user_id': 'f3f734f9-a3e1-4b68-8207-7f638fa3878b',
#   'timestamp': '2026-01-13T22:08:38.447779+00:00',
#   'amount': 368.47,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_112',
#   'product_category': 'gambling',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'paypal',
#   'location': '{"lat":73.7832895,"lon":177.968159}',
#   'ip_address': '67.17.141.73',
#   'device_info': '{"os":"Windows","browser":"Chrome"}',
#   'user_agent': 'Opera/9.14.(X11; Linux x86_64; th-TH) Presto/2.9.188 Version/11.00',
#   'account_age_days': 955,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '53a96480-6ef0-4471-8b9b-067ea8494c5c',
#   'user_id': '718f59da-50eb-49bc-8039-e53de1523605',
#   'timestamp': '2026-01-13T22:08:38.821812+00:00',
#   'amount': 350.19,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_101',
#   'product_category': 'travel',
#   'transaction_type': 'transfer',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-52.1965795,"lon":-57.394239}',
#   'ip_address': '156.148.106.35',
#   'device_info': '{"os":"Other","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Linux; Android 14) AppleWebKit/531.2 (KHTML, like Gecko) Chrome/20.0.864.0 Safari/531.2',
#   'account_age_days': 587,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'a0e6f943-ae1a-4753-ac0d-eb8633db20ee',
#   'user_id': '8dce6718-76db-4163-bebd-94cbbcc8d6bb',
#   'timestamp': '2026-01-13T22:08:38.989596+00:00',
#   'amount': 126.9,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_173',
#   'product_category': 'groceries',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":15.9074475,"lon":-94.438145}',
#   'ip_address': '112.233.92.146',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:1.9.7.20) Gecko/8031-01-08 14:44:45.255035 Firefox/9.0',
#   'account_age_days': 33,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '2b9b70c0-0556-479a-be3a-5861d202fdf1',
#   'user_id': '2bc3285f-cd1d-498f-9486-c626b0118d73',
#   'timestamp': '2026-01-13T22:08:39.347183+00:00',
#   'amount': 214.36,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_81',
#   'product_category': 'gambling',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'paypal',
#   'location': '{"lat":43.836709,"lon":82.266286}',
#   'ip_address': '5.28.252.190',
#   'device_info': '{"os":"Linux","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/536.0 (KHTML, like Gecko) Chrome/21.0.834.0 Safari/536.0',
#   'account_age_days': 521,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '279beade-9d23-4140-946e-14ea3367233c',
#   'user_id': '9ae791a3-1e24-4fb7-a638-6d07d44ac07c',
#   'timestamp': '2026-01-13T22:08:39.645371+00:00',
#   'amount': 436.03,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_165',
#   'product_category': 'luxury_items',
#   'transaction_type': 'transfer',
#   'payment_method': 'crypto',
#   'location': '{"lat":44.7919905,"lon":-68.067522}',
#   'ip_address': '97.200.171.36',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 5.0; Trident/5.1)',
#   'account_age_days': 1703,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '4832d61f-ab14-49d1-af4c-718e1dad463a',
#   'user_id': '59e6516a-d680-4569-bc0b-5920b0e0c006',
#   'timestamp': '2026-01-13T22:08:40.146916+00:00',
#   'amount': 8.08,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_139',
#   'product_category': 'gambling',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'crypto',
#   'location': '{"lat":15.788993,"lon":-4.860855}',
#   'ip_address': '20.156.6.211',
#   'device_info': '{"os":"macOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPad; CPU iPad OS 9_3_6 like Mac OS X) AppleWebKit/531.0 (KHTML, like Gecko) FxiOS/11.1y0004.0 Mobile/15F216 Safari/531.0',
#   'account_age_days': 99,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'b98671a5-3253-4b39-bc74-678842fa1bb0',
#   'user_id': 'd4580842-6c41-4d43-a639-7b74db1cd123',
#   'timestamp': '2026-01-13T22:08:40.499819+00:00',
#   'amount': 450.84,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_1',
#   'product_category': 'clothing',
#   'transaction_type': 'purchase',
#   'payment_method': 'paypal',
#   'location': '{"lat":46.017022,"lon":-48.967181}',
#   'ip_address': '223.231.205.57',
#   'device_info': '{"os":"Other","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 5.2; Trident/4.1)',
#   'account_age_days': 128,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '09332e09-1dd0-4edc-87b2-55baf849a747',
#   'user_id': 'c3699c9c-9071-4138-8f9b-21e387357ba4',
#   'timestamp': '2026-01-13T22:08:40.758946+00:00',
#   'amount': 325.74,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_42',
#   'product_category': 'luxury_items',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":39.4332185,"lon":-91.506814}',
#   'ip_address': '97.64.95.154',
#   'device_info': '{"os":"Other","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Windows 98) AppleWebKit/535.0 (KHTML, like Gecko) Chrome/29.0.831.0 Safari/535.0',
#   'account_age_days': 593,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9b9fbd6f-947c-4816-9b3e-d98e45e88abf',
#   'user_id': 'bc618801-ff7d-4116-a617-ba89b009a58f',
#   'timestamp': '2026-01-13T22:08:41.192968+00:00',
#   'amount': 9.18,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_126',
#   'product_category': 'luxury_items',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":-61.6278635,"lon":139.314712}',
#   'ip_address': '149.96.101.130',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_5_8 rv:6.0; wo-SN) AppleWebKit/533.33.7 (KHTML, like Gecko) Version/4.1 Safari/533.33.7',
#   'account_age_days': 954,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '7bedb580-283d-4139-9a69-484245420c0f',
#   'user_id': '8f5907d9-a447-42eb-a0a6-e77d4556ffea',
#   'timestamp': '2026-01-13T22:08:41.255029+00:00',
#   'amount': 220.14,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_148',
#   'product_category': 'gambling',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":13.9256355,"lon":0.4969}',
#   'ip_address': '58.40.124.218',
#   'device_info': '{"os":"Windows","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; PPC Mac OS X 10_12_4 rv:5.0; mg-MG) AppleWebKit/534.12.3 (KHTML, like Gecko) Version/5.0.1 Safari/534.12.3',
#   'account_age_days': 701,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'df0bce9a-80b4-4b56-96d8-a1d2fe9114d9',
#   'user_id': 'ef2ff72d-af31-418a-bd26-fa742decb439',
#   'timestamp': '2026-01-13T22:08:41.325473+00:00',
#   'amount': 144.75,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_140',
#   'product_category': 'luxury_items',
#   'transaction_type': 'purchase',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-20.485139,"lon":107.251644}',
#   'ip_address': '109.125.71.218',
#   'device_info': '{"os":"iOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.1)',
#   'account_age_days': 1543,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '810217ef-539b-4f91-82a5-0e20a155f74d',
#   'user_id': '18249e32-4e7d-48a3-bf99-fb82b32743e7',
#   'timestamp': '2026-01-13T22:08:41.414609+00:00',
#   'amount': 296.38,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_87',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-23.544962,"lon":134.063602}',
#   'ip_address': '38.139.108.206',
#   'device_info': '{"os":"Android","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 10.0) AppleWebKit/531.25.6 (KHTML, like Gecko) Version/4.0 Safari/531.25.6',
#   'account_age_days': 1291,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '4dfb957b-5e1d-4e09-9504-c8fcbc364199',
#   'user_id': '01fd156a-e8ca-43d3-8770-b9b91ed95e6c',
#   'timestamp': '2026-01-13T22:08:41.594911+00:00',
#   'amount': 188.55,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_124',
#   'product_category': 'services',
#   'transaction_type': 'purchase',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-14.0184245,"lon":106.678594}',
#   'ip_address': '182.25.181.153',
#   'device_info': '{"os":"Windows","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 11.0; Trident/5.1)',
#   'account_age_days': 1315,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '7763b20e-7dbe-4b83-b998-d99dbf84361b',
#   'user_id': '4196ce4b-8166-46c3-86b9-0ebf6c21e922',
#   'timestamp': '2026-01-13T22:08:42.006310+00:00',
#   'amount': 119.94,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_54',
#   'product_category': 'groceries',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":-58.6727845,"lon":79.109311}',
#   'ip_address': '31.227.251.189',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 8_4_1 like Mac OS X) AppleWebKit/531.0 (KHTML, like Gecko) FxiOS/9.9z4922.0 Mobile/82A480 Safari/531.0',
#   'account_age_days': 1371,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'e945567c-91ac-4855-9cb3-eff4c5d065e8',
#   'user_id': 'f3ce4695-9e2d-40ce-9d09-3aeac26d3c59',
#   'timestamp': '2026-01-13T22:08:42.175284+00:00',
#   'amount': 27.41,
#   'currency': 'USD',
#   'merchant_id': 'merchant_120',
#   'product_category': 'other',
#   'transaction_type': 'deposit',
#   'payment_method': 'credit_card',
#   'location': '{"lat":35.2014125,"lon":-102.142471}',
#   'ip_address': '31.35.60.75',
#   'device_info': '{"os":"Other","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (iPod; U; CPU iPhone OS 3_0 like Mac OS X; sat-IN) AppleWebKit/531.18.1 (KHTML, like Gecko) Version/3.0.5 Mobile/8B115 Safari/6531.18.1',
#   'account_age_days': 730,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '2762c95c-14aa-4fa6-bb4d-4c697330056f',
#   'user_id': 'c0a6c136-59bb-4d60-b675-80951e8a892b',
#   'timestamp': '2026-01-13T22:08:42.334686+00:00',
#   'amount': 363.95,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_194',
#   'product_category': 'digital_goods',
#   'transaction_type': 'payment',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-39.557404,"lon":-122.399722}',
#   'ip_address': '6.12.5.217',
#   'device_info': '{"os":"Linux","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.0) AppleWebKit/531.47.7 (KHTML, like Gecko) Version/5.1 Safari/531.47.7',
#   'account_age_days': 381,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '7b8687bd-94a1-4a9e-8b00-4a10900e476d',
#   'user_id': '9839fb97-814f-472a-8277-0b8cdde57810',
#   'timestamp': '2026-01-13T22:08:42.400887+00:00',
#   'amount': 31.3,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_146',
#   'product_category': 'electronics',
#   'transaction_type': 'transfer',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-7.8502085,"lon":-16.106962}',
#   'ip_address': '92.163.39.191',
#   'device_info': '{"os":"iOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.2; Trident/5.1)',
#   'account_age_days': 1381,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'be631a0d-d511-42ef-9ad7-a4caff4b58aa',
#   'user_id': '5d7dec90-1d5e-4676-8d6a-b2045eab09cf',
#   'timestamp': '2026-01-13T22:08:42.500722+00:00',
#   'amount': 362.37,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_61',
#   'product_category': 'electronics',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":23.926186,"lon":-89.969728}',
#   'ip_address': '51.200.109.95',
#   'device_info': '{"os":"Linux","browser":"Opera"}',
#   'user_agent': 'Opera/9.38.(Windows CE; ve-ZA) Presto/2.9.162 Version/10.00',
#   'account_age_days': 1379,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '692336cd-895a-453c-9687-a71b9d910123',
#   'user_id': '2866d5b7-55db-4dc6-bdbf-c20da9ac7718',
#   'timestamp': '2026-01-13T22:08:42.665493+00:00',
#   'amount': 426.78,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_151',
#   'product_category': 'groceries',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-48.6744195,"lon":-18.604111}',
#   'ip_address': '24.32.32.115',
#   'device_info': '{"os":"Linux","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 6.2; Trident/3.0)',
#   'account_age_days': 357,
#   'cvv_provided': False,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '2b19f878-b7f7-4740-b191-672581aeb8e9',
#   'user_id': '0a8b3b6f-5f51-4dc4-a28b-5bcd83d7495f',
#   'timestamp': '2026-01-13T22:08:42.751263+00:00',
#   'amount': 74.09,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_33',
#   'product_category': 'groceries',
#   'transaction_type': 'transfer',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-58.7589695,"lon":111.593366}',
#   'ip_address': '170.84.196.13',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 6.0; Trident/3.0)',
#   'account_age_days': 381,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '99c24101-ec50-440d-92cb-1116fd612ac9',
#   'user_id': 'b3e90e11-1ccb-445e-89bd-a883f8b024b3',
#   'timestamp': '2026-01-13T22:08:42.886957+00:00',
#   'amount': 265.12,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_124',
#   'product_category': 'travel',
#   'transaction_type': 'transfer',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-40.2350855,"lon":74.851979}',
#   'ip_address': '197.151.86.20',
#   'device_info': '{"os":"macOS","browser":"Other"}',
#   'user_agent': 'Opera/8.35.(X11; Linux i686; ast-ES) Presto/2.9.179 Version/10.00',
#   'account_age_days': 209,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '5b404334-ff4b-45ed-a22e-ec966f2ddcf9',
#   'user_id': 'a258f44e-5af7-4fb4-a564-d5da561b32ce',
#   'timestamp': '2026-01-13T22:08:43.175576+00:00',
#   'amount': 409.09,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_42',
#   'product_category': 'groceries',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":-40.9550705,"lon":89.337763}',
#   'ip_address': '60.217.253.165',
#   'device_info': '{"os":"Linux","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 6.2; Trident/4.0)',
#   'account_age_days': 672,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '2002c5ab-33dd-47c9-b7b9-7a0309b35b65',
#   'user_id': '90cc3380-945b-4bf7-b00a-fe8b1a8dabeb',
#   'timestamp': '2026-01-13T22:08:43.452731+00:00',
#   'amount': 256.78,
#   'currency': 'USD',
#   'merchant_id': 'merchant_134',
#   'product_category': 'luxury_items',
#   'transaction_type': 'transfer',
#   'payment_method': 'crypto',
#   'location': '{"lat":6.5818155,"lon":16.246687}',
#   'ip_address': '70.250.191.4',
#   'device_info': '{"os":"macOS","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_8_6) AppleWebKit/536.2 (KHTML, like Gecko) Chrome/48.0.893.0 Safari/536.2',
#   'account_age_days': 1545,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '06ff6f50-c67b-4900-bbb5-1925c4369e1f',
#   'user_id': '00afe82a-193e-4382-8b0b-705945bb9145',
#   'timestamp': '2026-01-13T22:08:43.790663+00:00',
#   'amount': 494.72,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_98',
#   'product_category': 'electronics',
#   'transaction_type': 'transfer',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-58.6797675,"lon":-79.420692}',
#   'ip_address': '36.115.11.148',
#   'device_info': '{"os":"Windows","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 4.0; Trident/4.1)',
#   'account_age_days': 1787,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'adcb76f4-04f0-4137-bf71-06ac7f02c158',
#   'user_id': '2e115a57-c435-4273-bc8e-78af44b92a86',
#   'timestamp': '2026-01-13T22:08:44.234749+00:00',
#   'amount': 21.77,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_141',
#   'product_category': 'clothing',
#   'transaction_type': 'payment',
#   'payment_method': 'crypto',
#   'location': '{"lat":33.8410575,"lon":142.739333}',
#   'ip_address': '44.233.56.139',
#   'device_info': '{"os":"Linux","browser":"Opera"}',
#   'user_agent': 'Opera/9.82.(Windows NT 6.1; brx-IN) Presto/2.9.168 Version/10.00',
#   'account_age_days': 1003,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '39cfcfdb-c30e-4a04-979a-e60ff3fee920',
#   'user_id': '4b196290-4e9e-4706-8906-2250f9fdb111',
#   'timestamp': '2026-01-13T22:08:44.307684+00:00',
#   'amount': 49.07,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_199',
#   'product_category': 'electronics',
#   'transaction_type': 'deposit',
#   'payment_method': 'paypal',
#   'location': '{"lat":-89.879436,"lon":-134.155662}',
#   'ip_address': '83.117.15.33',
#   'device_info': '{"os":"Windows","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 4_2_1 like Mac OS X) AppleWebKit/535.2 (KHTML, like Gecko) CriOS/34.0.860.0 Mobile/45G254 Safari/535.2',
#   'account_age_days': 1051,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '0f2f9e04-4d12-4f17-b18f-4015836bba9e',
#   'user_id': '5f1d4f87-30cd-42ef-ae90-698926546f4a',
#   'timestamp': '2026-01-13T22:08:44.586472+00:00',
#   'amount': 96.14,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_125',
#   'product_category': 'clothing',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-4.8612495,"lon":48.375493}',
#   'ip_address': '36.162.199.46',
#   'device_info': '{"os":"macOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/533.1 (KHTML, like Gecko) Chrome/23.0.852.0 Safari/533.1',
#   'account_age_days': 562,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'e254c805-809a-4214-9790-9a0463b4e803',
#   'user_id': 'fa8bbb72-39da-48eb-935d-9bde5af1f2ec',
#   'timestamp': '2026-01-13T22:08:44.836820+00:00',
#   'amount': 374.51,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_29',
#   'product_category': 'luxury_items',
#   'transaction_type': 'transfer',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-14.396074,"lon":122.687768}',
#   'ip_address': '104.110.148.6',
#   'device_info': '{"os":"macOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPod; U; CPU iPhone OS 3_2 like Mac OS X; ber-MA) AppleWebKit/531.39.3 (KHTML, like Gecko) Version/3.0.5 Mobile/8B114 Safari/6531.39.3',
#   'account_age_days': 394,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '018c8f1d-576a-4125-9fb3-11e8a17db52c',
#   'user_id': 'ba43d106-e812-4761-a540-e8d0160b5136',
#   'timestamp': '2026-01-13T22:08:44.995481+00:00',
#   'amount': 23.27,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_134',
#   'product_category': 'gambling',
#   'transaction_type': 'deposit',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":1.2446665,"lon":-151.95325}',
#   'ip_address': '131.100.109.251',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_9; rv:1.9.6.20) Gecko/7362-08-13 17:08:32.031921 Firefox/3.6.13',
#   'account_age_days': 401,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'd1c072d4-6c8b-4227-91f5-6fb73c9a7c6b',
#   'user_id': 'f79135d7-3bc8-45a2-a2a9-9ec84e6985a4',
#   'timestamp': '2026-01-13T22:08:45.158939+00:00',
#   'amount': 154.8,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_108',
#   'product_category': 'electronics',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":43.961443,"lon":10.247737}',
#   'ip_address': '180.68.39.21',
#   'device_info': '{"os":"iOS","browser":"Safari"}',
#   'user_agent': 'Opera/8.21.(Windows NT 5.1; bn-BD) Presto/2.9.164 Version/12.00',
#   'account_age_days': 1174,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '6cc43f4d-c59d-47ee-bf54-951670fe4f46',
#   'user_id': '81e6aa65-f1af-4939-b396-b527ac8c1a0f',
#   'timestamp': '2026-01-13T22:08:45.317375+00:00',
#   'amount': 381.16,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_30',
#   'product_category': 'electronics',
#   'transaction_type': 'deposit',
#   'payment_method': 'credit_card',
#   'location': '{"lat":26.848467,"lon":96.083909}',
#   'ip_address': '178.163.27.97',
#   'device_info': '{"os":"macOS","browser":"Safari"}',
#   'user_agent': 'Opera/9.33.(Windows NT 6.2; sv-SE) Presto/2.9.163 Version/10.00',
#   'account_age_days': 134,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '65bd90e2-fbce-455e-9d47-da3b5cea4cf4',
#   'user_id': 'ceb7bee7-e525-407a-9f9f-527d4277c707',
#   'timestamp': '2026-01-13T22:08:45.564415+00:00',
#   'amount': 66.25,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_170',
#   'product_category': 'groceries',
#   'transaction_type': 'payment',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-53.500402,"lon":122.858811}',
#   'ip_address': '120.241.187.15',
#   'device_info': '{"os":"Windows","browser":"Edge"}',
#   'user_agent': 'Opera/8.40.(Windows 95; so-SO) Presto/2.9.175 Version/11.00',
#   'account_age_days': 976,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'd60eda8e-2356-4e1d-91e3-492ab0b7ea24',
#   'user_id': '063442ca-1005-4aa6-8c4e-b739bf09ceb3',
#   'timestamp': '2026-01-13T22:08:45.890243+00:00',
#   'amount': 475.67,
#   'currency': 'USD',
#   'merchant_id': 'merchant_183',
#   'product_category': 'digital_goods',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-87.381576,"lon":8.264959}',
#   'ip_address': '211.80.195.147',
#   'device_info': '{"os":"Other","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gecko/5201-09-13 07:56:07.412491 Firefox/3.6.6',
#   'account_age_days': 1145,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '19fcf24f-19da-41b4-90b4-70450c06fb57',
#   'user_id': 'ba2401f7-3697-49e0-ae30-1ce9a258180f',
#   'timestamp': '2026-01-13T22:08:46.302821+00:00',
#   'amount': 480.48,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_114',
#   'product_category': 'clothing',
#   'transaction_type': 'payment',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":5.097269,"lon":-3.300934}',
#   'ip_address': '149.201.103.79',
#   'device_info': '{"os":"Windows","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Android 4.4.4; Mobile; rv:22.0) Gecko/22.0 Firefox/22.0',
#   'account_age_days': 880,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '7295ccf1-cb3c-4144-ae79-20c20373863e',
#   'user_id': '95ede1a1-0fed-4e93-85d5-b90472ff31fa',
#   'timestamp': '2026-01-13T22:08:46.720172+00:00',
#   'amount': 213.83,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_35',
#   'product_category': 'services',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":72.61908,"lon":-118.204915}',
#   'ip_address': '204.37.161.76',
#   'device_info': '{"os":"Other","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 5.2) AppleWebKit/534.1 (KHTML, like Gecko) Chrome/56.0.888.0 Safari/534.1',
#   'account_age_days': 246,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'f0400e55-0448-4038-803f-49f8af584245',
# ...
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '3db1b3f1-ba08-41d8-a563-cac37b5d7102',
#   'user_id': 'd78cee38-d407-47d2-81f5-45add1f4aa0b',
#   'timestamp': '2026-01-13T22:06:58.269855+00:00',
#   'amount': 473.31,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_85',
#   'product_category': 'gambling',
#   'transaction_type': 'transfer',
#   'payment_method': 'crypto',
#   'location': '{"lat":-67.480247,"lon":106.425069}',
#   'ip_address': '115.7.9.162',
#   'device_info': '{"os":"Linux","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gecko/6788-12-01 11:05:33.625946 Firefox/3.6.15',
#   'account_age_days': 861,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '70630d6b-9ee3-4821-96f9-b447b5ee2152',
#   'user_id': '0ddfc2fb-2580-4655-94f1-b1e1f1029a42',
#   'timestamp': '2026-01-13T22:06:58.494204+00:00',
#   'amount': 432.72,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_193',
#   'product_category': 'travel',
#   'transaction_type': 'payment',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-50.9238725,"lon":74.893062}',
#   'ip_address': '182.37.68.29',
#   'device_info': '{"os":"macOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Android 2.0.1; Mobile; rv:10.0) Gecko/10.0 Firefox/10.0',
#   'account_age_days': 1688,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'd3e78675-0eab-45da-a610-1783f5f2f713',
#   'user_id': '5418d9a3-46d6-46ac-a95e-46039cf1000b',
#   'timestamp': '2026-01-13T22:06:58.726442+00:00',
#   'amount': 301.0,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_109',
#   'product_category': 'clothing',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":62.3054575,"lon":157.664743}',
#   'ip_address': '150.109.236.242',
#   'device_info': '{"os":"Linux","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Android 5.0; Mobile; rv:31.0) Gecko/31.0 Firefox/31.0',
#   'account_age_days': 798,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'a8b117bd-90e1-4b2c-8f20-dc6fdcffbcc9',
#   'user_id': '761f2486-f27d-4bff-add2-778bedd28462',
#   'timestamp': '2026-01-13T22:06:58.848823+00:00',
#   'amount': 107.11,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_116',
#   'product_category': 'clothing',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":66.4563995,"lon":-115.354972}',
#   'ip_address': '222.252.29.247',
#   'device_info': '{"os":"Windows","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (iPad; CPU iPad OS 6_1_6 like Mac OS X) AppleWebKit/535.1 (KHTML, like Gecko) CriOS/21.0.854.0 Mobile/07K237 Safari/535.1',
#   'account_age_days': 544,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '5aeffce3-1a1d-44ee-a2b1-c3870b538689',
#   'user_id': '5f91f608-0bbd-449e-95f5-0b817eef2c00',
#   'timestamp': '2026-01-13T22:06:58.963801+00:00',
#   'amount': 463.58,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_98',
#   'product_category': 'gambling',
#   'transaction_type': 'payment',
#   'payment_method': 'paypal',
#   'location': '{"lat":-56.050189,"lon":-45.979958}',
#   'ip_address': '48.89.68.46',
#   'device_info': '{"os":"Other","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Linux; Android 4.2.2) AppleWebKit/533.1 (KHTML, like Gecko) Chrome/36.0.868.0 Safari/533.1',
#   'account_age_days': 874,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '71be4e16-35a6-43e8-a885-044a8e2cbcd8',
#   'user_id': '0f0e6c91-a837-41c2-81b9-1fe22d6809f2',
#   'timestamp': '2026-01-13T22:06:59.088605+00:00',
#   'amount': 495.72,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_25',
#   'product_category': 'luxury_items',
#   'transaction_type': 'transfer',
#   'payment_method': 'paypal',
#   'location': '{"lat":-48.9744555,"lon":11.719218}',
#   'ip_address': '142.2.168.216',
#   'device_info': '{"os":"macOS","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.0) AppleWebKit/535.9.6 (KHTML, like Gecko) Version/4.1 Safari/535.9.6',
#   'account_age_days': 1672,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'e526f096-0cc2-4c92-8043-6abdce2de87d',
#   'user_id': '9bb35ab5-2fa3-4950-973f-c7c7c7176def',
#   'timestamp': '2026-01-13T22:06:59.517831+00:00',
#   'amount': 387.79,
#   'currency': 'EUR',
#   'merchant_id': 'merchant_101',
#   'product_category': 'luxury_items',
#   'transaction_type': 'withdrawal',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":38.1767885,"lon":-170.655187}',
#   'ip_address': '13.46.41.189',
#   'device_info': '{"os":"Android","browser":"Firefox"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 10.0; Trident/4.1)',
#   'account_age_days': 1046,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '01caaf23-366b-4e4b-b695-5a5b17702b70',
#   'user_id': '6d5186be-d391-42f0-ae94-8615270631f7',
#   'timestamp': '2026-01-13T22:06:59.687764+00:00',
#   'amount': 86.6,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_78',
#   'product_category': 'other',
#   'transaction_type': 'payment',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-0.7084605,"lon":178.986542}',
#   'ip_address': '128.34.142.92',
#   'device_info': '{"os":"iOS","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_1) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/20.0.845.0 Safari/532.2',
#   'account_age_days': 1087,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '0877c63c-8786-4c50-88d8-610bae07e65b',
#   'user_id': '5f94ce94-2e3e-4e1e-b304-c7cbe74f34f2',
#   'timestamp': '2026-01-13T22:06:59.835714+00:00',
#   'amount': 310.22,
#   'currency': 'USD',
#   'merchant_id': 'merchant_163',
#   'product_category': 'electronics',
#   'transaction_type': 'transfer',
#   'payment_method': 'debit_card',
#   'location': '{"lat":28.885825,"lon":159.661765}',
#   'ip_address': '175.109.65.77',
#   'device_info': '{"os":"Linux","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/3.1)',
#   'account_age_days': 1561,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '856ae316-1c55-4ce6-ad5b-88f85df1191d',
#   'user_id': '4ad999dc-3940-4470-a75e-9f8a3826b532',
#   'timestamp': '2026-01-13T22:07:00.166809+00:00',
#   'amount': 316.12,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_3',
#   'product_category': 'digital_goods',
#   'transaction_type': 'purchase',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":30.0537755,"lon":21.74925}',
#   'ip_address': '142.56.119.31',
#   'device_info': '{"os":"iOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 10.0; Trident/3.0)',
#   'account_age_days': 1066,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'f65e88ca-09d6-40ac-b8fd-5cd969ecbba4',
#   'user_id': '440a3edf-5c67-42a6-9c48-00c95a5d974f',
#   'timestamp': '2026-01-13T22:07:00.350886+00:00',
#   'amount': 131.71,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_73',
#   'product_category': 'electronics',
#   'transaction_type': 'transfer',
#   'payment_method': 'crypto',
#   'location': '{"lat":-49.125262,"lon":159.675365}',
#   'ip_address': '160.173.69.34',
#   'device_info': '{"os":"Linux","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 6.0; Trident/4.0)',
#   'account_age_days': 1682,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '0b7f4a78-301d-492d-9b09-c1520a33c37f',
#   'user_id': '003adada-05e6-4d3f-8d3e-548668280c59',
#   'timestamp': '2026-01-13T22:07:00.747811+00:00',
#   'amount': 395.25,
#   'currency': 'JPY',
#   'merchant_id': 'merchant_2',
#   'product_category': 'services',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":29.7453045,"lon":30.327089}',
#   'ip_address': '92.253.108.159',
#   'device_info': '{"os":"iOS","browser":"Other"}',
#   'user_agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3 rv:4.0; lb-LU) AppleWebKit/531.16.1 (KHTML, like Gecko) Version/5.0.4 Safari/531.16.1',
#   'account_age_days': 1660,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'ab13cc4c-3d9d-4303-9586-bd7b316633b0',
#   'user_id': '9de504b1-bcc8-42ed-8053-86caa2d514a7',
#   'timestamp': '2026-01-13T22:07:00.928722+00:00',
#   'amount': 288.78,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_110',
#   'product_category': 'travel',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-3.565204,"lon":101.716154}',
#   'ip_address': '68.182.42.68',
#   'device_info': '{"os":"Other","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 4.0; Trident/5.0)',
#   'account_age_days': 789,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'b36802e7-0fed-4058-8af7-415815c9f5e2',
#   'user_id': 'f5f97b1a-a905-441b-8fb5-ad8ef01f3842',
#   'timestamp': '2026-01-13T22:07:01.165698+00:00',
#   'amount': 494.25,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_87',
#   'product_category': 'digital_goods',
#   'transaction_type': 'payment',
#   'payment_method': 'debit_card',
#   'location': '{"lat":-24.616201,"lon":24.918914}',
#   'ip_address': '192.61.116.224',
#   'device_info': '{"os":"Linux","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 6.2; tr-CY; rv:1.9.2.20) Gecko/4535-07-10 08:41:45.497421 Firefox/5.0',
#   'account_age_days': 279,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '9f1e3783-735c-43d2-914e-84c6d975a2f0',
#   'user_id': '585b1901-fca5-438d-9e7a-2e79f6d87a73',
#   'timestamp': '2026-01-13T22:07:01.629794+00:00',
#   'amount': 162.6,
#   'currency': 'USD',
#   'merchant_id': 'merchant_35',
#   'product_category': 'groceries',
#   'transaction_type': 'transfer',
#   'payment_method': 'crypto',
#   'location': '{"lat":44.6989945,"lon":-140.129553}',
#   'ip_address': '92.150.192.44',
#   'device_info': '{"os":"Linux","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Android 4.3.1; Mobile; rv:32.0) Gecko/32.0 Firefox/32.0',
#   'account_age_days': 160,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '39846336-e69a-4e8b-b8c9-fc6f917872de',
#   'user_id': '2ebed3ef-8090-4ec9-9692-8d227c5aa081',
#   'timestamp': '2026-01-13T22:07:01.978367+00:00',
#   'amount': 89.72,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_56',
#   'product_category': 'other',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-6.0075055,"lon":-107.009871}',
#   'ip_address': '51.74.231.214',
#   'device_info': '{"os":"macOS","browser":"Chrome"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/534.2 (KHTML, like Gecko) Chrome/37.0.858.0 Safari/534.2',
#   'account_age_days': 1295,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '5c94b772-2bb0-47f8-8300-f62fd69ee95e',
#   'user_id': '04574190-106b-4bd7-a061-9894e24d8f90',
#   'timestamp': '2026-01-13T22:07:02.419961+00:00',
#   'amount': 96.2,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_101',
#   'product_category': 'electronics',
#   'transaction_type': 'transfer',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-12.841275,"lon":-176.34492}',
#   'ip_address': '130.201.156.197',
#   'device_info': '{"os":"Other","browser":"Edge"}',
#   'user_agent': 'Opera/8.50.(X11; Linux x86_64; aa-ER) Presto/2.9.182 Version/11.00',
#   'account_age_days': 77,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'acfb76f0-7228-40a4-95cb-e2ba3fab3e91',
#   'user_id': '6fdb87f0-373a-4145-a263-a9165c6a50a0',
#   'timestamp': '2026-01-13T22:07:02.641159+00:00',
#   'amount': 210.95,
#   'currency': 'CAD',
#   'merchant_id': 'merchant_56',
#   'product_category': 'groceries',
#   'transaction_type': 'deposit',
#   'payment_method': 'crypto',
#   'location': '{"lat":-32.047464,"lon":-16.656891}',
#   'ip_address': '126.96.221.122',
#   'device_info': '{"os":"Android","browser":"Safari"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 9_3_5 like Mac OS X) AppleWebKit/531.1 (KHTML, like Gecko) CriOS/45.0.886.0 Mobile/63K420 Safari/531.1',
#   'account_age_days': 1106,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'b2f90039-18aa-413d-a875-147e95d9a9df',
#   'user_id': 'e8541af0-495b-4683-a0f8-fad11d2f692a',
#   'timestamp': '2026-01-13T22:07:03.008008+00:00',
#   'amount': 442.4,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_163',
#   'product_category': 'other',
#   'transaction_type': 'purchase',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-60.220377,"lon":149.428372}',
#   'ip_address': '17.92.179.160',
#   'device_info': '{"os":"Android","browser":"Opera"}',
#   'user_agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 14_2 like Mac OS X) AppleWebKit/534.0 (KHTML, like Gecko) CriOS/26.0.852.0 Mobile/80F254 Safari/534.0',
#   'account_age_days': 166,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': 'f0c15566-2d13-404d-a488-ba4e7555e9f6',
#   'user_id': 'd56e3b7b-8e83-49d8-ae52-5ad2fdbdbe55',
#   'timestamp': '2026-01-13T22:07:03.295945+00:00',
#   'amount': 806.9,
#   'currency': 'BRL',
#   'merchant_id': 'merchant_144',
#   'product_category': 'digital_goods',
#   'transaction_type': 'deposit',
#   'payment_method': 'credit_card',
#   'location': '{"lat":-67.9371995,"lon":178.168419}',
#   'ip_address': '143.215.230.242',
#   'device_info': '{"os":"Other","browser":"Other"}',
#   'user_agent': 'Opera/8.99.(Windows NT 11.0; dv-MV) Presto/2.9.188 Version/12.00',
#   'account_age_days': 1464,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 1},
#  {'transaction_id': '39dce626-694f-40e0-86c5-faf9f66d0901',
#   'user_id': '38d5fd98-7d9b-4810-9fbf-e071e85be8b9',
#   'timestamp': '2026-01-13T22:07:03.428810+00:00',
#   'amount': 91.3,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_34',
#   'product_category': 'groceries',
#   'transaction_type': 'deposit',
#   'payment_method': 'bank_transfer',
#   'location': '{"lat":-8.958949,"lon":153.096536}',
#   'ip_address': '4.199.222.149',
#   'device_info': '{"os":"iOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/21.0.825.0 Safari/535.2',
#   'account_age_days': 1769,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '258a812c-537f-44d3-8d88-74f1c5af49a2',
#   'user_id': '6b02a5fc-1789-4e3f-a3af-6c63f332b091',
#   'timestamp': '2026-01-13T22:07:03.585432+00:00',
#   'amount': 368.3,
#   'currency': 'AUD',
#   'merchant_id': 'merchant_119',
#   'product_category': 'services',
#   'transaction_type': 'purchase',
#   'payment_method': 'crypto',
#   'location': '{"lat":65.935948,"lon":-17.505313}',
#   'ip_address': '205.20.247.117',
#   'device_info': '{"os":"macOS","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/534.1 (KHTML, like Gecko) Chrome/16.0.836.0 Safari/534.1',
#   'account_age_days': 1059,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0},
#  {'transaction_id': '0b519282-6db7-42fb-af36-ca5e00b91bee',
#   'user_id': 'a6499e73-701d-4aa3-9f5b-3e9ff0d48d3e',
#   'timestamp': '2026-01-13T22:07:03.908668+00:00',
#   'amount': 199.41,
#   'currency': 'GBP',
#   'merchant_id': 'merchant_174',
#   'product_category': 'digital_goods',
#   'transaction_type': 'purchase',
#   'payment_method': 'credit_card',
#   'location': '{"lat":87.54451,"lon":-18.745467}',
#   'ip_address': '220.236.58.122',
#   'device_info': '{"os":"Linux","browser":"Edge"}',
#   'user_agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/533.2 (KHTML, like Gecko) Chrome/25.0.870.0 Safari/533.2',
#   'account_age_days': 1477,
#   'cvv_provided': True,
#   'billing_address_match': True,
#   'is_fraud': 0}]

# %%
for sample in samples:
    pprint(sample)
    break
# Out:
# {'account_age_days': 657,
#  'amount': 35.62,
#  'billing_address_match': True,
#  'currency': 'GBP',
#  'cvv_provided': True,
#  'device_info': '{"os":"Windows","browser":"Other"}',
#  'ip_address': '157.23.223.51',
#  'is_fraud': 0,
#  'location': '{"lat":-3.685515,"lon":61.184191}',
#  'merchant_id': 'merchant_53',
#  'payment_method': 'debit_card',
#  'product_category': 'digital_goods',
#  'timestamp': '2026-01-13T22:08:26.555237+00:00',
#  'transaction_id': 'ee583be0-c39d-4c17-ab99-9e941b0a7606',
#  'transaction_type': 'deposit',
#  'user_agent': 'Mozilla/5.0 (compatible; MSIE 9.0; Windows 98; Trident/3.0)',
#  'user_id': '1b02783e-492a-4820-9d44-46a343e6420a'}

# %%
class CustomOrdinalEncoder:
    """
    An incremental ordinal encoder that is picklable and processes dictionaries.
    Assigns a unique integer ID to each unique category encountered for each feature.
    """
    def __init__(self):
        # Dictionary to store mappings for each feature.
        # Keys are feature names (from input dictionary), values are dictionaries
        # mapping category value to integer ID for that feature.
        self._feature_mappings: Dict[Hashable, Dict[Any, int]] = {}
        # Dictionary to store the next available integer ID for each feature.
        # Keys are feature names, values are integers.
        self._feature_next_ids: Dict[Hashable, int] = {}
    def learn_one(self, x: Dict[Hashable, Any]):
        """
        Learns categories from a single sample dictionary.
        Iterates through the dictionary's items and learns each category value
        for its corresponding feature.
        Args:
            x: A dictionary representing a single sample.
               Keys are feature names, values are feature values.
               Assumes categorical features are present in this dictionary.
        """
        for feature_name, category_value in x.items():
            # Ensure the category value is hashable (dictionaries/lists are not)
            # You might need more sophisticated type checking or handling
            # if your input dictionaries contain complex unhashable types
            if not isinstance(category_value, Hashable):
                 print(f"Warning: Skipping unhashable value for feature '{feature_name}': {category_value}")
                 continue # Skip this feature for learning
            # If this is the first time we see this feature, initialize its mapping and counter
            if feature_name not in self._feature_mappings:
                self._feature_mappings[feature_name] = {}
                self._feature_next_ids[feature_name] = 0
            # Get the mapping and counter for this specific feature
            feature_map = self._feature_mappings[feature_name]
            feature_next_id = self._feature_next_ids[feature_name]
            # Check if the category value is already in the mapping for this feature
            if category_value not in feature_map:
                # If it's a new category for this feature, assign the next available ID
                feature_map[category_value] = feature_next_id
                # Increment the counter for the next new category for this feature
                self._feature_next_ids[feature_name] += 1
    def transform_one(self, x: Dict[Hashable, Any]) -> Dict[Hashable, int]:
        """
        Transforms categorical features in a single sample dictionary into integer IDs.
        Args:
            x: A dictionary representing a single sample.
               Keys are feature names, values are feature values.
        Returns:
            A new dictionary containing the transformed integer IDs for the
            categorical features that the encoder has seen. Features not
            seen by the encoder are excluded from the output dictionary.
        Raises:
            KeyError: If a feature is seen but a specific category value
                      within that feature has not been seen during learning.
                      You might want to add logic here to handle unseen categories
                      (e.g., return a default value like -1 or NaN for that feature).
        """
        transformed_sample: Dict[Hashable, int] = {}
        for feature_name, category_value in x.items():
            # Only attempt to transform features that the encoder has seen
            if feature_name in self._feature_mappings:
                feature_map = self._feature_mappings[feature_name]
                # Check if the category value for this feature has been seen
                if category_value in feature_map:
                    # Transform the category value using the feature's mapping
                    transformed_sample[feature_name] = feature_map[category_value]
                else:
                    # Handle unseen category values for a known feature
                    # By default, this will raise a KeyError as per the docstring.
                    # Example: return a placeholder value instead of raising error:
                    # transformed_sample[feature_name] = -1 # Or some other indicator
                    # print(f"Warning: Unseen category '{category_value}' for feature '{feature_name}' during transform.")
                    # Or raise the error explicitly:
                    raise KeyError(f"Unseen category '{category_value}' for feature '{feature_name}' during transform.")
            # Features not in self._feature_mappings are ignored in the output.
            # If you need to include them (e.g., original numerical features),
            # you would copy them over here. This encoder only outputs encoded features.
        return transformed_sample
    def get_feature_mappings(self) -> Dict[Hashable, Dict[Any, int]]:
        """Returns the current mappings for all features."""
        return self._feature_mappings
    def get_feature_next_ids(self) -> Dict[Hashable, int]:
        """Returns the next available IDs for all features."""
        return self._feature_next_ids
    def __repr__(self) -> str:
        """String representation of the encoder."""
        num_features = len(self._feature_mappings)
        feature_details = ", ".join([f"{name}: {len(mapping)} categories" for name, mapping in self._feature_mappings.items()])
        return f"CustomPicklableOrdinalEncoder(features={num_features} [{feature_details}])"

# %%
class DictImputer(base.Transformer):
    """
    Imputes missing values (None or missing keys) for specified features in a dictionary.

    Parameters
    ----------
    on
        List of feature names to impute.
    fill_value
        The value to use for imputation.
    """
    def __init__(self, on: list, fill_value):
        self.on = on
        self.fill_value = fill_value
    def transform_one(self, x: dict):
        x_transformed = x.copy()
        for feature in self.on:
            if x_transformed.get(feature) is None:
                x_transformed[feature] = self.fill_value
        return x_transformed

# %%
def extract_device_info(x):
    x_ = x['device_info']
    # Parse JSON string if coming from Delta Lake
    if isinstance(x_, str):
        x_ = orjson.loads(x_)
    return {
        'os': x_['os'],
        'browser': x_['browser'],
    }

def extract_timestamp_info(x):
    x_ = dt.datetime.strptime(
        x['timestamp'],
        "%Y-%m-%dT%H:%M:%S.%f%z")
    return {
        'year': x_.year,
        'month': x_.month,
        'day': x_.day,
        'hour': x_.hour,
        'minute': x_.minute,
        'second': x_.second
    }

def extract_coordinates(x):
    x_ = x['location']
    # Parse JSON string if coming from Delta Lake
    if isinstance(x_, str):
        x_ = orjson.loads(x_)
    return {
        'lat': x_['lat'],
        'lon': x_['lon'],
    }

# %%
def process_sample(x, encoders, project_name):
    """Process a single sample for River incremental learning."""
    if project_name == "Transaction Fraud Detection":
        pipe1 = compose.Select(
            "amount",
            "account_age_days",
            "cvv_provided",
            "billing_address_match"
        )
        pipe1.learn_one(x)
        x1 = pipe1.transform_one(x)
        pipe2 = compose.Select(
            "currency",
            "merchant_id",
            "payment_method",
            "product_category",
            "transaction_type",
        )
        pipe2.learn_one(x)
        x_pipe_2 = pipe2.transform_one(x)
        pipe3a = compose.Select("device_info")
        pipe3a.learn_one(x)
        x_pipe_3 = pipe3a.transform_one(x)
        pipe3b = compose.FuncTransformer(extract_device_info)
        pipe3b.learn_one(x_pipe_3)
        x_pipe_3 = pipe3b.transform_one(x_pipe_3)
        pipe4a = compose.Select("timestamp")
        pipe4a.learn_one(x)
        x_pipe_4 = pipe4a.transform_one(x)
        pipe4b = compose.FuncTransformer(extract_timestamp_info)
        pipe4b.learn_one(x_pipe_4)
        x_pipe_4 = pipe4b.transform_one(x_pipe_4)
        x_to_encode = x_pipe_2 | x_pipe_3 | x_pipe_4
        encoders["ordinal_encoder"].learn_one(x_to_encode)
        x2 = encoders["ordinal_encoder"].transform_one(x_to_encode)
        return x1 | x2, {"ordinal_encoder": encoders["ordinal_encoder"]}
    elif project_name == "Estimated Time of Arrival":
        pipe1 = compose.Select(
            'estimated_distance_km',
            'temperature_celsius',
            'hour_of_day',
            'driver_rating',
            'initial_estimated_travel_time_seconds',
            'debug_traffic_factor',
            'debug_weather_factor',
            'debug_incident_delay_seconds',
            'debug_driver_factor'
        )
        pipe1.learn_one(x)
        x1 = pipe1.transform_one(x)
        pipe2 = compose.Select(
            'driver_id',
            'vehicle_id',
            'weather',
            'vehicle_type'
        )
        pipe2.learn_one(x)
        x_pipe_2 = pipe2.transform_one(x)
        pipe3a = compose.Select(
            "timestamp",
        )
        pipe3a.learn_one(x)
        x_pipe_3 = pipe3a.transform_one(x)
        pipe3b = compose.FuncTransformer(
            extract_timestamp_info,
        )
        pipe3b.learn_one(x_pipe_3)
        x_pipe_3 = pipe3b.transform_one(x_pipe_3)
        x_to_encode = x_pipe_2 | x_pipe_3
        encoders["ordinal_encoder"].learn_one(x_to_encode)
        x2 = encoders["ordinal_encoder"].transform_one(x_to_encode)
        return x1 | x2, {
            "ordinal_encoder": encoders["ordinal_encoder"]
        }
    elif project_name == "E-Commerce Customer Interactions":
        pipe1 = compose.Select(
            'price',
            'quantity',
            'session_event_sequence',
            'time_on_page_seconds'
        )
        pipe1.learn_one(x)
        x1 = pipe1.transform_one(x)
        pipe2 = compose.Select(
            'event_type',
            'product_category',
            'product_id',
            'referrer_url',
        )
        pipe2.learn_one(x)
        x_pipe_2 = pipe2.transform_one(x)
        pipe3a = compose.Select(
            "device_info"
        )
        pipe3a.learn_one(x)
        x_pipe_3 = pipe3a.transform_one(x)
        pipe3b = compose.FuncTransformer(
            extract_device_info,
        )
        pipe3b.learn_one(x_pipe_3)
        x_pipe_3 = pipe3b.transform_one(x_pipe_3)
        pipe4a = compose.Select(
            "timestamp",
        )
        pipe4a.learn_one(x)
        x_pipe_4 = pipe4a.transform_one(x)
        pipe4b = compose.FuncTransformer(
            extract_timestamp_info,
        )
        pipe4b.learn_one(x_pipe_4)
        x_pipe_4 = pipe4b.transform_one(x_pipe_4)
        pipe5a = compose.Select(
            "location",
        )
        pipe5a.learn_one(x)
        x_pipe_5 = pipe5a.transform_one(x)
        pipe5b = compose.FuncTransformer(
            extract_coordinates,
        )
        pipe5b.learn_one(x_pipe_5)
        x_pipe_5 = pipe5b.transform_one(x_pipe_5)
        x_to_prep = x1 | x_pipe_2 | x_pipe_3 | x_pipe_4 | x_pipe_5
        x_to_prep = DictImputer(
            fill_value = False, 
            on = list(x_to_prep.keys())).transform_one(
                x_to_prep)
        numerical_features = [
            'price',
            'session_event_sequence',
            'time_on_page_seconds',
            'quantity'
        ]
        categorical_features = [
            'event_type',
            'product_category',
            'product_id',
            'referrer_url',
            'os',
            'browser',
            'year',
            'month',
            'day',
            'hour',
            'minute',
            'second'
        ]
        num_pipe = compose.Select(*numerical_features)
        num_pipe.learn_one(x_to_prep)
        x_num = num_pipe.transform_one(x_to_prep)
        cat_pipe = compose.Select(*categorical_features)
        cat_pipe.learn_one(x_to_prep)
        x_cat = cat_pipe.transform_one(x_to_prep)
        encoders["standard_scaler"].learn_one(x_num)
        x_scaled = encoders["standard_scaler"].transform_one(x_num)
        encoders["feature_hasher"].learn_one(x_cat)
        x_hashed = encoders["feature_hasher"].transform_one(x_cat)
        return x_scaled | x_hashed, {
            "standard_scaler": encoders["standard_scaler"], 
            "feature_hasher": encoders["feature_hasher"]
        }
    elif project_name == "Sales Forecasting":
        pipe1 = compose.Select(
            'concept_drift_stage',
            'day_of_week',
            'is_holiday',
            'is_promotion_active',
            'month',
            #'total_sales_amount',
            'unit_price'
        )
        pipe1.learn_one(x)
        x1 = pipe1.transform_one(x)
        pipe2a = compose.Select(
            "timestamp",
        )
        pipe2a.learn_one(x)
        x_pipe_2 = pipe2a.transform_one(x)
        pipe2b = compose.FuncTransformer(
            extract_timestamp_info,
        )
        pipe2b.learn_one(x_pipe_2)
        x2 = pipe2b.transform_one(x_pipe_2)
        pipe3a = compose.Select(
            'product_id',
            'promotion_id',
            'store_id'
        )
        pipe3a.learn_one(x)
        x3 = pipe3a.transform_one(x)
        x_to_process = x1 | x2 | x3
        numerical_features = [
            'unit_price',
            #'total_sales_amount',
        ]
        categorical_features = [
            'is_promotion_active',
            'is_holiday',
            'day_of_week',
            'concept_drift_stage',
            'year',
            'month',
            'day',
            #'hour',
            #'minute',
            #'second',
            'product_id',
            'promotion_id',
            'store_id',
        ]
        pipe_num = compose.Select(*numerical_features)
        pipe_num.learn_one(x_to_process)
        x_num = pipe_num.transform_one(x_to_process)
        pipe_cat = compose.Select(*categorical_features)
        pipe_cat.learn_one(x_to_process)
        x_cat = pipe_cat.transform_one(x_to_process)
        encoders["standard_scaler"].learn_one(x_num)
        x_num = encoders["standard_scaler"].transform_one(x_num)
        encoders["one_hot_encoder"].learn_one(x_cat)
        x_cat = encoders["one_hot_encoder"].transform_one(x_cat)
        return x_num | x_cat, {
            "one_hot_encoder": encoders["one_hot_encoder"],
            "standard_scaler": encoders["standard_scaler"],
        }

# %%
def _create_default_model(project_name):
    """Create default model based on project type.

    Models are configured based on River ML documentation and best practices.
    All parameters are documented with their River ML defaults and rationale.

    See: https://riverml.xyz/latest/
    """
    if project_name == "Transaction Fraud Detection":
        # =================================================================
        # ARFClassifier - Adaptive Random Forest Classifier
        # For fraud detection with concept drift handling
        # =================================================================
        # OLD CONFIGURATION:
        # return forest.ARFClassifier(
        #     n_models = 10,
        #     drift_detector = drift.ADWIN(),
        #     warning_detector = drift.ADWIN(),
        #     metric = metrics.ROCAUC(),
        #     max_features = "sqrt",
        #     lambda_value = 6,
        #     seed = 42
        # )

        # CONFIGURATION based on River ML documentation:
        # Reference: https://riverml.xyz/latest/api/forest/ARFClassifier/
        # Reference: https://riverml.xyz/latest/examples/imbalanced-learning/
        #
        # - n_models=10: Default number of trees in ensemble
        # - max_features="sqrt": Default, sqrt of features per split
        # - lambda_value=6: Default Leveraging Bagging parameter
        # - metric=ROCAUC(): RECOMMENDED by River for imbalanced fraud detection
        #   (River's imbalanced-learning guide uses ROCAUC for fraud detection)
        # - disable_weighted_vote=False: Enable weighted voting for better accuracy
        # - drift_detector ADWIN(delta=0.002): Default sensitivity (0.002)
        # - warning_detector ADWIN(delta=0.01): Default warning sensitivity
        # - grace_period=50: Default observations between split attempts
        # - max_depth=None: Default, unlimited tree depth
        # - split_criterion="info_gain": Default, information gain criterion
        # - delta=0.01: Default allowed error in split decision
        # - tau=0.05: Default tie-breaking threshold
        # - leaf_prediction="nba": Default, Naive Bayes Adaptive
        # - nb_threshold=0: Default, enable NB immediately
        # - binary_split=False: Default, allow multi-way splits
        # - min_branch_fraction=0.01: Default minimum data per branch
        # - max_share_to_split=0.99: Default majority class proportion
        # - max_size=100.0: Default max memory in MiB
        # - memory_estimate_period=2000000: Default instances between memory checks
        # - merit_preprune=True: Default merit-based pre-pruning
        return forest.ARFClassifier(
            n_models = 10,
            max_features = "sqrt",
            lambda_value = 6,
            metric = metrics.ROCAUC(),
            disable_weighted_vote = False,
            drift_detector = drift.ADWIN(delta = 0.002),
            warning_detector = drift.ADWIN(delta = 0.01),
            grace_period = 50,
            max_depth = None,
            split_criterion = "info_gain",
            delta = 0.01,
            tau = 0.05,
            leaf_prediction = "nba",
            nb_threshold = 0,
            nominal_attributes = None,
            binary_split = False,
            min_branch_fraction = 0.01,
            max_share_to_split = 0.99,
            max_size = 100.0,
            memory_estimate_period = 2000000,
            stop_mem_management = False,
            remove_poor_attrs = False,
            merit_preprune = True,
            seed = 42,
        )
    elif project_name == "Estimated Time of Arrival":
        # =================================================================
        # ARFRegressor - Adaptive Random Forest Regressor
        # For ETA prediction with continuous drift handling
        # =================================================================
        # OLD CONFIGURATION:
        # return forest.ARFRegressor(
        #     n_models = 10,
        #     drift_detector = drift.ADWIN(),
        #     warning_detector = drift.ADWIN(),
        #     metric = metrics.RMSE(),
        #     max_features = "sqrt",
        #     lambda_value = 6,
        #     seed = 42
        # )

        # CONFIGURATION based on River ML documentation:
        # Reference: https://riverml.xyz/latest/api/forest/ARFRegressor/
        #
        # - n_models=10: Default number of trees
        # - max_features="sqrt": Default feature selection
        # - aggregation_method="median": Default, robust to outliers
        # - lambda_value=6: Default Leveraging Bagging parameter
        # - metric=MAE(): Using MAE as it's common for ETA prediction
        # - disable_weighted_vote=True: Default for regressor
        # - drift_detector ADWIN(delta=0.002): Default sensitivity
        # - warning_detector ADWIN(delta=0.01): Default warning sensitivity
        # - grace_period=50: Default observations between split attempts
        # - max_depth=None: Default unlimited depth
        # - delta=0.01: Default allowed error
        # - tau=0.05: Default tie-breaking threshold
        # - leaf_prediction="adaptive": Default, dynamically chooses mean/model
        # - model_selector_decay=0.95: Default decay for leaf model selection
        # - min_samples_split=5: Default minimum samples for split
        # - binary_split=False: Default multi-way splits
        # - max_size=500.0: Default max memory in MiB
        return forest.ARFRegressor(
            n_models=10,
            max_features="sqrt",
            aggregation_method="median",
            lambda_value=6,
            metric=metrics.MAE(),
            disable_weighted_vote=True,
            drift_detector=drift.ADWIN(delta=0.002),
            warning_detector=drift.ADWIN(delta=0.01),
            grace_period=50,
            max_depth=None,
            delta=0.01,
            tau=0.05,
            leaf_prediction="adaptive",
            leaf_model=None,
            model_selector_decay=0.95,
            min_samples_split=5,
            binary_split=False,
            max_size=500.0,
            memory_estimate_period=2000000,
            nominal_attributes=None,
            seed=42,
        )
    elif project_name == "E-Commerce Customer Interactions":
        # =================================================================
        # DBSTREAM - Density-Based Stream Clustering
        # For customer behavior clustering with arbitrary shapes
        # =================================================================
        # OLD CONFIGURATION:
        # return cluster.DBSTREAM(
        #     clustering_threshold = 1.0,
        #     fading_factor = 0.01,
        #     cleanup_interval = 2,
        # )

        # CONFIGURATION based on River ML documentation example:
        # Reference: https://riverml.xyz/latest/api/cluster/DBSTREAM/
        #
        # The River documentation provides this exact example configuration:
        # - clustering_threshold=1.5: Micro-cluster radius
        # - fading_factor=0.05: Historical data importance (must be > 0)
        # - cleanup_interval=4: Time between cleanup processes
        # - intersection_factor=0.5: Cluster overlap ratio for connectivity
        # - minimum_weight=1.0: Threshold for non-noisy cluster classification
        return cluster.DBSTREAM(
            clustering_threshold=1.5,
            fading_factor=0.05,
            cleanup_interval=4,
            intersection_factor=0.5,
            minimum_weight=1.0,
        )
    elif project_name == "Sales Forecasting":
        # =================================================================
        # SNARIMAX - Seasonal Non-linear Auto-Regressive Integrated
        # Moving Average with eXogenous inputs
        # For sales forecasting with weekly seasonality
        # =================================================================
        # OLD CONFIGURATION:
        # regressor_snarimax = linear_model.PARegressor(
        #     C = 0.01,
        #     mode = 1)
        # return time_series.SNARIMAX(
        #     p = 2,
        #     d = 1,
        #     q = 1,
        #     m = 7,
        #     sp = 1,
        #     sd = 0,
        #     sq = 1,
        #     regressor = regressor_snarimax
        # )

        # CONFIGURATION based on River ML documentation:
        # Reference: https://riverml.xyz/latest/api/time-series/SNARIMAX/
        # Reference: https://riverml.xyz/latest/api/linear-model/PARegressor/
        #
        # SNARIMAX parameters for weekly sales data:
        # - p=7: Past 7 days of target values (full week)
        # - d=1: First-order differencing for trend removal
        # - q=2: Past error terms for noise handling
        # - m=7: Weekly seasonality period
        # - sp=1: Seasonal autoregressive order
        # - sd=1: Seasonal differencing (recommended for seasonal data)
        # - sq=1: Seasonal moving average order
        #
        # PARegressor parameters (defaults from River docs):
        # - C=1.0: Default regularization strength
        # - mode=1: Default algorithm mode
        # - eps=0.1: Default tolerance parameter
        # - learn_intercept=True: Default bias learning
        regressor_snarimax = linear_model.PARegressor(
            C=1.0,
            mode=1,
            eps=0.1,
            learn_intercept=True,
        )
        return time_series.SNARIMAX(
            p=7,
            d=1,
            q=2,
            m=7,
            sp=1,
            sd=1,
            sq=1,
            regressor=regressor_snarimax,
        )
    else:
        raise ValueError(f"Unknown project: {project_name}")

# %%
def _create_default_encoders(project_name):
    """Create default encoders based on project type."""
    if project_name in ["Transaction Fraud Detection", "Estimated Time of Arrival"]:
        return {"ordinal_encoder": CustomOrdinalEncoder()}
    elif project_name == "E-Commerce Customer Interactions":
        return {
            "standard_scaler": preprocessing.StandardScaler(),
            "feature_hasher": preprocessing.FeatureHasher()
        }
    elif project_name == "Sales Forecasting":
        return {
            "one_hot_encoder": preprocessing.OneHotEncoder(),
            "standard_scaler": preprocessing.StandardScaler(),
        }
    else:
        raise ValueError(f"Unknown project: {project_name}")

# %%
dir(metrics)
# Out:
# ['Accuracy',
#  'AdjustedMutualInfo',
#  'AdjustedRand',
#  'BalancedAccuracy',
#  'ClassificationReport',
#  'CohenKappa',
#  'Completeness',
#  'ConfusionMatrix',
#  'CrossEntropy',
#  'F1',
#  'FBeta',
#  'FowlkesMallows',
#  'GeometricMean',
#  'Homogeneity',
#  'Jaccard',
#  'LogLoss',
#  'MAE',
#  'MAPE',
#  'MCC',
#  'MSE',
#  'MacroF1',
#  'MacroFBeta',
#  'MacroJaccard',
#  'MacroPrecision',
#  'MacroRecall',
#  'MicroF1',
#  'MicroFBeta',
#  'MicroJaccard',
#  'MicroPrecision',
#  'MicroRecall',
#  'MultiFBeta',
#  'MutualInfo',
#  'NormalizedMutualInfo',
#  'Precision',
#  'R2',
#  'RMSE',
#  'RMSLE',
#  'ROCAUC',
#  'Rand',
#  'Recall',
#  'RollingROCAUC',
#  'SMAPE',
#  'Silhouette',
#  'VBeta',
#  'WeightedF1',
#  'WeightedFBeta',
#  'WeightedJaccard',
#  'WeightedPrecision',
#  'WeightedRecall',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'accuracy',
#  'annotations',
#  'balanced_accuracy',
#  'base',
#  'confusion',
#  'cross_entropy',
#  'efficient_rollingrocauc',
#  'expected_mutual_info',
#  'fbeta',
#  'fowlkes_mallows',
#  'geometric_mean',
#  'jaccard',
#  'kappa',
#  'log_loss',
#  'mae',
#  'mape',
#  'mcc',
#  'mse',
#  'multioutput',
#  'mutual_info',
#  'precision',
#  'r2',
#  'rand',
#  'recall',
#  'report',
#  'roc_auc',
#  'rolling_roc_auc',
#  'silhouette',
#  'smape',
#  'vbeta']

# %%
model = _create_default_model(PROJECT_NAME)
encoders = _create_default_encoders(PROJECT_NAME)

# =============================================================================
# RIVER ML METRICS CONFIGURATION FOR TRANSACTION FRAUD DETECTION
# =============================================================================
# Research-based optimal configuration for real-time TFD training.
# Sources:
#   - River ML Documentation: https://riverml.xyz/dev/api/metrics/
#   - Fraud Detection Best Practices: https://www.cesarsotovalero.net/blog/
#     evaluation-metrics-for-real-time-financial-fraud-detection-ml-models.html
#   - F-Beta Score Guide: https://machinelearningmastery.com/fbeta-measure-for-ml
# =============================================================================

# Shared confusion matrix for efficiency (multiple metrics share same CM)
# BENEFIT: Reduces computation, metrics share TP/TN/FP/FN counts
shared_cm = metrics.ConfusionMatrix()

# -----------------------------------------------------------------------------
# CLASS-BASED METRICS (use predict_one - class labels)
# -----------------------------------------------------------------------------
# These metrics compare predicted class (0/1) vs actual class (0/1)
# All use shared_cm for efficiency
# pos_val=1 means fraud (is_fraud=1) is the positive class
# -----------------------------------------------------------------------------
class_metric_classes = {
    # PRIMARY METRICS (most important for fraud detection)
    "Recall": metrics.Recall,       # TP / (TP + FN) - catch rate of fraud
    "Precision": metrics.Precision, # TP / (TP + FP) - accuracy of fraud alerts
    "F1": metrics.F1,               # Harmonic mean (beta=1, balanced)
    "FBeta": metrics.FBeta,         # Weighted harmonic mean (configurable beta)
    # SECONDARY METRICS (additional insights)
    "Accuracy": metrics.Accuracy,           # Overall correct predictions
    "BalancedAccuracy": metrics.BalancedAccuracy,  # Mean recall per class
    "MCC": metrics.MCC,             # Matthews Correlation Coefficient
    "GeometricMean": metrics.GeometricMean, # sqrt(TPR * TNR) - imbalance robust
    "CohenKappa": metrics.CohenKappa,       # Agreement beyond chance
    "Jaccard": metrics.Jaccard,     # TP / (TP + FP + FN) - IoU for positive class
}
class_metric_args = {
    # PRIMARY METRICS
    "Recall": {"cm": shared_cm, "pos_val": 1},
    "Precision": {"cm": shared_cm, "pos_val": 1},
    "F1": {"cm": shared_cm, "pos_val": 1},
    # FBeta with beta=2.0: Industry standard for fraud detection
    # beta=2.0 weights Recall 2x more than Precision (prioritize catching fraud)
    # Alternative: beta=0.5 if customer experience (fewer false positives) is priority
    # Reference: https://www.analyticsvidhya.com/blog/2024/12/f-beta-score/
    "FBeta": {"beta": 2.0, "cm": shared_cm, "pos_val": 1},
    # SECONDARY METRICS
    "Accuracy": {"cm": shared_cm},
    "BalancedAccuracy": {"cm": shared_cm},
    # MCC: One of best metrics for imbalanced data per research
    # Reference: https://link.springer.com/article/10.1186/s12864-019-6413-7
    "MCC": {"cm": shared_cm, "pos_val": 1},
    "GeometricMean": {"cm": shared_cm},
    "CohenKappa": {"cm": shared_cm},
    "Jaccard": {"cm": shared_cm, "pos_val": 1},
}

# -----------------------------------------------------------------------------
# PROBABILITY-BASED METRICS (use predict_proba_one - probabilities)
# -----------------------------------------------------------------------------
# These metrics use predicted probability of fraud (0.0 to 1.0)
# Better for threshold optimization and model calibration assessment
# -----------------------------------------------------------------------------
proba_metric_classes = {
    "ROCAUC": metrics.ROCAUC,
    "RollingROCAUC": metrics.RollingROCAUC,
    "LogLoss": metrics.LogLoss,
}
proba_metric_args = {
    # ROCAUC: Approximation of true ROC AUC for streaming data
    # n_thresholds: Higher = more accurate but more memory/CPU
    # Default=10, River example uses 20, production recommended=50
    # Reference: https://riverml.xyz/dev/api/metrics/ROCAUC/
    "ROCAUC": {"n_thresholds": 50, "pos_val": 1},
    
    # RollingROCAUC: Windowed ROCAUC for concept drift detection
    # window_size: Number of recent samples to consider
    # Default=1000, but for rare fraud (~1-5%), need larger window
    # With window=5000 and 2% fraud rate, expect ~100 fraud samples
    # This provides stable AUC while detecting recent drift
    "RollingROCAUC": {"window_size": 5000, "pos_val": 1},
    
    # LogLoss: Measures probability calibration (lower = better)
    # 0.693 is random baseline, target < 0.1 for good calibration
    # No configurable parameters
    "LogLoss": {},
}

# -----------------------------------------------------------------------------
# MATRIX/REPORT METRICS (no .get(), display separately)
# -----------------------------------------------------------------------------
# These metrics don't return a single scalar value
# ConfusionMatrix: Shows TP, TN, FP, FN distribution
# ClassificationReport: Comprehensive per-class statistics
# -----------------------------------------------------------------------------
report_metric_classes = {
    "ConfusionMatrix": metrics.ConfusionMatrix,
    "ClassificationReport": metrics.ClassificationReport,
}
report_metric_args = {
    # Separate ConfusionMatrix for report (not shared_cm)
    "ConfusionMatrix": {},
    # decimals=4: More precision for monitoring subtle changes
    # Uses shared_cm for efficiency with class_metrics
    "ClassificationReport": {"decimals": 4, "cm": shared_cm},
}

# =============================================================================
# INSTANTIATE ALL METRICS
# =============================================================================
class_metrics = {
    name: class_metric_classes[name](**class_metric_args[name])
    for name in class_metric_classes
}
proba_metrics = {
    name: proba_metric_classes[name](**proba_metric_args[name])
    for name in proba_metric_classes
}
report_metrics = {
    name: report_metric_classes[name](**report_metric_args[name])
    for name in report_metric_classes
}

# =============================================================================
# TRAINING LOOP
# =============================================================================
for sample in tqdm.tqdm(samples):
    x, encoders = process_sample(sample, encoders, PROJECT_NAME)
    y = sample['is_fraud']
    # Update the model (learn from this sample)
    model.learn_one(x, y)
    # Get predictions AFTER learning (prequential evaluation)
    prediction = model.predict_one(x)
    prediction_proba = model.predict_proba_one(x)
    # Extract probability of positive class (fraud=1)
    # Handle case where model returns None or empty dict
    proba_positive = prediction_proba.get(1, 0.0) if prediction_proba else 0.0
    # Update class-based metrics (use class prediction: 0 or 1)
    for metric in class_metrics.values():
        metric.update(y, prediction)
    # Update probability-based metrics (use probability: 0.0 to 1.0)
    for metric in proba_metrics.values():
        metric.update(y, proba_positive)
    # Update report metrics (use class prediction)
    for metric in report_metrics.values():
        metric.update(y, prediction)

# =============================================================================
# COLLECT SCALAR METRICS FOR LOGGING
# =============================================================================
# Combine class + proba metrics (all have .get() method)
metrics_to_log = {}
for name, metric in class_metrics.items():
    metrics_to_log[name] = metric.get()
for name, metric in proba_metrics.items():
    metrics_to_log[name] = metric.get()

metrics_to_log
# Out:
# 100%|██████████| 1000/1000 [00:19<00:00, 52.13it/s]
# {'Recall': 0.4166666666666667,
#  'Precision': 1.0,
#  'F1': 0.5882352941176471,
#  'FBeta': 0.4716981132075472,
#  'Accuracy': 0.993,
#  'BalancedAccuracy': 0.7083333333333334,
#  'MCC': 0.6432226235010586,
#  'GeometricMean': np.float64(0.6454972243679028),
#  'CohenKappa': 0.5853080568720405,
#  'Jaccard': 0.4166666666666667,
#  'ROCAUC': np.float64(0.9017375168690958),
#  'RollingROCAUC': 0.9224021592442645,
#  'LogLoss': 0.03484638887493995}

# %%
# Display report metrics (ConfusionMatrix, ClassificationReport)
print("Confusion Matrix:")
print(report_metrics["ConfusionMatrix"])
print("\nClassification Report:")
print(report_metrics["ClassificationReport"])
# Out:
# Confusion Matrix:
#     0     1
# 0   988   0
# 1     7   5
#
# Classification Report:
#            Precision   Recall      F1         Support
#
#    False    99.2965%   100.0000%   99.6470%     10868
#     True   100.0000%    41.6667%   58.8235%       132
#
#    Macro    99.6482%    70.8333%   79.2353%
#    Micro    99.3000%    99.3000%   99.3000%
# Weighted    99.3049%    99.3000%   99.1571%
#
#                    99.3000% accuracy
